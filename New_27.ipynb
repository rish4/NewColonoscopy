# %% [markdown]
# <a href="https://colab.research.google.com/github/rish4/NewColonoscopy/blob/main/New_27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc
import keras
import tensorflow as tf
from keras import backend as K
from keras import metrics
from keras.regularizers import l2
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, InputLayer, Activation
from keras.preprocessing.image import ImageDataGenerator
from keras.metrics import AUC
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix
from keras import models
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
import numpy as np
from keras.preprocessing import image
from IPython.display import display
from PIL import Image

# %% [markdown]
# **Default Kernel Initializer(glorot_uniform)**

# %%
## Set file paths to image files

train_path1 = "/content/drive/MyDrive/NewDB/Training set"
test_path1 = "/content/drive/MyDrive/NewDB/Test set"

## Set up hyperparameters that will be used later
hyper_dimension1 = 128
hyper_batch_size1 = 32
hyper_channels1 = 3
hyper_mode1 = 'rgb'

## Generate batches of image data (train, validation, and test) with data augmentation
train_datagen1 = ImageDataGenerator(rescale=1.0/255.0, 
                                   shear_range = 0.2,
                                   zoom_range = 0.2, 
                                   horizontal_flip = True )

test_datagen1 = ImageDataGenerator(rescale=1.0/255.0) 

train_generator1 = train_datagen1.flow_from_directory(directory = train_path1, 
                                                    target_size = (hyper_dimension1, hyper_dimension1),
                                                    batch_size = hyper_batch_size1, 
                                                    color_mode = hyper_mode1,
                                                    class_mode = 'binary', 
                                                    seed = 42)

test_generator1 = test_datagen1.flow_from_directory(directory = test_path1, 
                                                 target_size = (hyper_dimension1, hyper_dimension1),
                                                 batch_size = hyper_batch_size1, 
                                                 class_mode = 'binary',
                                                 color_mode = hyper_mode1,
                                                 shuffle=False,
                                                 seed = 42)

test_generator1.reset()
# Out:
# Found 1656 images belonging to 2 classes.
# Found 415 images belonging to 2 classes.

# %%
cnn1 = Sequential()
cnn1.add(InputLayer(input_shape=(hyper_dimension1, hyper_dimension1, hyper_channels1)))

cnn1.add(Conv2D(filters=16, kernel_size=3, activation='relu'))
cnn1.add(MaxPooling2D(pool_size=(2,2)))

cnn1.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn1.add(MaxPooling2D(pool_size=(2,2)))

cnn1.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
cnn1.add(MaxPooling2D(pool_size=(2,2)))

cnn1.add(Flatten())

cnn1.add(Dense(activation='relu', units=128))
cnn1.add(Dense(activation='sigmoid', units=1))

cnn1.summary()

cnn1.compile(optimizer= 'adam', loss='binary_crossentropy', metrics=['accuracy'])
cnn_model1 = cnn1.fit_generator(train_generator1, 
                              steps_per_epoch = len(train_generator1), 
                              epochs = 50, 
                              validation_data = test_generator1,
                              validation_steps = len(test_generator1)
                              )
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 126, 126, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 61, 61, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 12544)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1605760
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 1,629,473
# Trainable params: 1,629,473
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 52/52 [==============================] - 658s 13s/step - loss: 0.6550 - accuracy: 0.6006 - val_loss: 0.5162 - val_accuracy: 0.7566
# Epoch 2/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.4921 - accuracy: 0.7516 - val_loss: 0.3607 - val_accuracy: 0.8699
# Epoch 3/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.4030 - accuracy: 0.8178 - val_loss: 0.3614 - val_accuracy: 0.8434
# Epoch 4/50
# 52/52 [==============================] - 57s 1s/step - loss: 0.3591 - accuracy: 0.8446 - val_loss: 0.2994 - val_accuracy: 0.8771
# Epoch 5/50
# 52/52 [==============================] - 57s 1s/step - loss: 0.3130 - accuracy: 0.8628 - val_loss: 0.3181 - val_accuracy: 0.8602
# Epoch 6/50
# 52/52 [==============================] - 57s 1s/step - loss: 0.2815 - accuracy: 0.8825 - val_loss: 0.2788 - val_accuracy: 0.8940
# Epoch 7/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.2828 - accuracy: 0.8851 - val_loss: 0.3129 - val_accuracy: 0.8723
# Epoch 8/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.2696 - accuracy: 0.8850 - val_loss: 0.2689 - val_accuracy: 0.9036
# Epoch 9/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.2311 - accuracy: 0.8950 - val_loss: 0.2786 - val_accuracy: 0.9012
# Epoch 10/50
# 52/52 [==============================] - 57s 1s/step - loss: 0.2416 - accuracy: 0.8964 - val_loss: 0.2638 - val_accuracy: 0.9060
# Epoch 11/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.2452 - accuracy: 0.9072 - val_loss: 0.2757 - val_accuracy: 0.8892
# Epoch 12/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.1942 - accuracy: 0.9267 - val_loss: 0.3079 - val_accuracy: 0.8771
# Epoch 13/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.
50
# 52/52 [==============================] - 57s 1s/step - loss: 0.0696 - accuracy: 0.9707 - val_loss: 0.1738 - val_accuracy: 0.9518
# Epoch 45/50
# 52/52 [==============================] - 57s 1s/step - loss: 0.0577 - accuracy: 0.9803 - val_loss: 0.2266 - val_accuracy: 0.9301
# Epoch 46/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.0489 - accuracy: 0.9853 - val_loss: 0.2261 - val_accuracy: 0.9325
# Epoch 47/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.0546 - accuracy: 0.9805 - val_loss: 0.2261 - val_accuracy: 0.9422
# Epoch 48/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.0769 - accuracy: 0.9756 - val_loss: 0.1765 - val_accuracy: 0.9398
# Epoch 49/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.0594 - accuracy: 0.9788 - val_loss: 0.2458 - val_accuracy: 0.9349
# Epoch 50/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.0437 - accuracy: 0.9851 - val_loss: 0.2735 - val_accuracy: 0.9133

# %%
def create_charts1(cnn, cnn_model):
    ## DEFINE ##
    ## Define 1:  train & validation loss
    train_loss = cnn_model.history['loss']
    val_loss = cnn_model.history['val_loss']
    
    ## Define 2: train & validation AUC
    train_auc_name = list(cnn_model.history.keys())[3]
    val_auc_name = list(cnn_model.history.keys())[1]
    train_auc = cnn_model.history[train_auc_name]
    val_auc = cnn_model.history[val_auc_name]
    
    ## Define 3: y_pred & y_true
    y_true = test_generator1.classes
    #print(y_true)
    Y_pred = cnn.predict_generator(test_generator1, steps = len(test_generator1))
    y_pred = (Y_pred > 0.5).T[0]
    #print(y_pred)
    y_pred_prob = Y_pred.T[0]
    #print(y_pred_prob)
    
    ## PLOT ##
    fig = plt.figure(figsize=(13, 10))
    
    ## PLOT 1: TRAIN VS. VALIDATION LOSS 
    plt.subplot(2,2,1)
    plt.title("Training vs. Validation Loss")
    plt.plot(train_loss, label='training loss')
    plt.plot(val_loss, label='validation loss')
    plt.xlabel("Number of Epochs", size=14)
    plt.legend()

    ## PLOT 2: TRAIN VS. VALIDATION AUC
    plt.subplot(2,2,2)
    plt.title("Training vs. Validation AUC Score")
    plt.plot(train_auc, label='training auc')
    plt.plot(val_auc, label='validation auc')
    plt.xlabel("Number of Epochs", size=14)
    plt.legend()
    
    ## PLOT 3: CONFUSION MATRIX
    plt.subplot(2,2,3)
      # Set up the labels for in the confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    names = ['True Negatives', 'False Positives', 'False Negatives', 'True Positives']
    counts = ['{0:0.0f}'.format(value) for value in cm.flatten()]
    percentages = ['{0:.2%}'.format(value) for value in cm.flatten()/np.sum(cm)]
    labels = [f'{v1}\n{v2}' for v1, v2 in zip(names, percentages)]
    labels = np.asarray(labels).reshape(2,2)
    ticklabels = ['Normal', 'Abnormal']

      # Create confusion matrix as heatmap
    sns.set(font_scale = 1.4)
    ax = sns.heatmap(cm, annot=labels, fmt='', cmap='Oranges', xticklabels=ticklabels, yticklabels=ticklabels )
    plt.xticks(size=12)
    plt.yticks(size=12)
    plt.title("Confusion Matrix") #plt.title("Confusion Matrix\n", fontsize=10)
    plt.xlabel("Predicted", size=14)
    plt.ylabel("Actual", size=14) 
    #plt.savefig('cm.png', transparent=True) 
    
    ## PLOT 4: ROC CURVE
    plt.subplot(2,2,4)
    fpr, tpr, thresholds = roc_curve(y_true, y_pred_prob)
    auc = roc_auc_score(y_true, y_pred_prob)
    plt.title('ROC Curve')
    plt.plot([0, 1], [0, 1], 'k--', label = "Random (AUC = 50%)")
    plt.plot(fpr, tpr, label='CNN (AUC = {:.2f}%)'.format(auc*100))
    plt.xlabel('False Positive Rate', size=14)
    plt.ylabel('True Positive Rate', size=14)
    plt.legend(loc='best')
    #plt.savefig('roc.png', bbox_inches='tight', pad_inches=1)
    
    ## END PLOTS
    plt.tight_layout()
    ;
    
    ## Summary Statistics
    TN, FP, FN, TP = cm.ravel() # cm[0,0], cm[0, 1], cm[1, 0], cm[1, 1]
    accuracy = (TP + TN) / np.sum(cm) # % positive out of all predicted positives
    precision = TP / (TP+FP) # % positive out of all predicted positives
    recall =  TP / (TP+FN) # % positive out of all supposed to be positives
    specificity = TN / (TN+FP) # % negative out of all supposed to be negatives
    f1 = 2*precision*recall / (precision + recall)
    stats_summary = '[Summary Statistics]\nAccuracy = {:.2%} | Precision = {:.2%} | Recall = {:.2%} | Specificity = {:.2%} | F1 Score = {:.2%}'.format(accuracy, precision, recall, specificity, f1)
    print(stats_summary)

# %%
create_charts1(cnn1, cnn_model1)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1976: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# [Summary Statistics]
# Accuracy = 61.93% | Precision = 63.51% | Recall = 62.33% | Specificity = 61.50% | F1 Score = 62.91%

# %% [markdown]
# **Uniform Kernel Initializer**

# %%
## Set file paths to image files

train_path2 = "/content/drive/MyDrive/NewDB/Training set"
test_path2 = "/content/drive/MyDrive/NewDB/Test set"

## Set up hyperparameters that will be used later
hyper_dimension2 = 128
hyper_batch_size2 = 32
hyper_channels2 = 3
hyper_mode2 = 'rgb'

## Generate batches of image data (train, validation, and test) with data augmentation
train_datagen2 = ImageDataGenerator(rescale=1.0/255.0, 
                                   shear_range = 0.2,
                                   zoom_range = 0.2, 
                                   horizontal_flip = True )

test_datagen2 = ImageDataGenerator(rescale=1.0/255.0) 

train_generator2 = train_datagen2.flow_from_directory(directory = train_path2, 
                                                    target_size = (hyper_dimension2, hyper_dimension2),
                                                    batch_size = hyper_batch_size2, 
                                                    color_mode = hyper_mode2,
                                                    class_mode = 'binary', 
                                                    seed = 42)

test_generator2 = test_datagen2.flow_from_directory(directory = test_path2, 
                                                 target_size = (hyper_dimension2, hyper_dimension2),
                                                 batch_size = hyper_batch_size2, 
                                                 class_mode = 'binary',
                                                 color_mode = hyper_mode2,
                                                 shuffle=False,
                                                 seed = 42)

test_generator2.reset()
# Out:
# Found 1656 images belonging to 2 classes.
# Found 415 images belonging to 2 classes.

# %%
cnn2 = Sequential()
cnn2.add(InputLayer(input_shape=(hyper_dimension2, hyper_dimension2, hyper_channels2)))

cnn2.add(Conv2D(filters=16, kernel_size=3, activation='relu', kernel_initializer='uniform'))
cnn2.add(MaxPooling2D(pool_size=(2,2)))

cnn2.add(Conv2D(filters=32, kernel_size=3, activation='relu', kernel_initializer='uniform'))
cnn2.add(MaxPooling2D(pool_size=(2,2)))

cnn2.add(Conv2D(filters=64, kernel_size=3, activation='relu', kernel_initializer='uniform'))
cnn2.add(MaxPooling2D(pool_size=(2,2)))

cnn2.add(Flatten())

cnn2.add(Dense(activation='relu', units=128))
cnn2.add(Dense(activation='sigmoid', units=1))

cnn2.summary()

cnn2.compile(optimizer= 'adam', loss='binary_crossentropy', metrics=['accuracy'])
cnn_model2 = cnn2.fit_generator(train_generator1, 
                              steps_per_epoch = len(train_generator2), 
                              epochs = 50, 
                              validation_data = test_generator2,
                              validation_steps = len(test_generator2)
                              )
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 126, 126, 16)      448
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 63, 63, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 61, 61, 32)        4640
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 28, 28, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 12544)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               1605760
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 1,629,473
# Trainable params: 1,629,473
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 52/52 [==============================] - 58s 1s/step - loss: 0.6853 - accuracy: 0.5353 - val_loss: 0.5359 - val_accuracy: 0.7229
# Epoch 2/50
# 52/52 [==============================] - 56s 1s/step - loss: 0
50
# 52/52 [==============================] - 56s 1s/step - loss: 0.1674 - accuracy: 0.9257 - val_loss: 0.2752 - val_accuracy: 0.9036
# Epoch 33/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.1277 - accuracy: 0.9449 - val_loss: 0.2647 - val_accuracy: 0.9036
# Epoch 34/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.1482 - accuracy: 0.9444 - val_loss: 0.2784 - val_accuracy: 0.9012
# Epoch 35/50
# 52/52 [==============================] - 55s 1s/step - loss: 0.1120 - accuracy: 0.9539 - val_loss: 0.3093 - val_accuracy: 0.9036
# Epoch 36/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.1356 - accuracy: 0.9319 - val_loss: 0.2650 - val_accuracy: 0.9060
# Epoch 37/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.0977 - accuracy: 0.9625 - val_loss: 0.3397 - val_accuracy: 0.8747
# Epoch 38/50
# 52/52 [==============================] - 55s 1s/step - loss: 0.1471 - accuracy: 0.9379 - val_loss: 0.2760 - val_accuracy: 0.9060
# Epoch 39/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.1189 - accuracy: 0.9528 - val_loss: 0.3422 - val_accuracy: 0.8892
# Epoch 40/50
# 52/52 [==============================] - 55s 1s/step - loss: 0.1260 - accuracy: 0.9483 - val_loss: 0.2578 - val_accuracy: 0.9181
# Epoch 41/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.1342 - accuracy: 0.9497 - val_loss: 0.4921 - val_accuracy: 0.8795
# Epoch 42/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.1218 - accuracy: 0.9544 - val_loss: 0.2631 - val_accuracy: 0.9012
# Epoch 43/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.1176 - accuracy: 0.9596 - val_loss: 0.2830 - val_accuracy: 0.9084
# Epoch 44/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.1127 - accuracy: 0.9561 - val_loss: 0.2931 - val_accuracy: 0.9036
# Epoch 45/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.0829 - accuracy: 0.9698 - val_loss: 0.3288 - val_accuracy: 0.9108
# Epoch 46/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.0949 - accuracy: 0.9684 - val_loss: 0.2772 - val_accuracy: 0.9036
# Epoch 47/50
# 52/52 [==============================] - 55s 1s/step - loss: 0.0875 - accuracy: 0.9643 - val_loss: 0.2544 - val_accuracy: 0.9181
# Epoch 48/50
# 52/52 [==============================] - 55s 1s/step - loss: 0.0904 - accuracy: 0.9674 - val_loss: 0.3280 - val_accuracy: 0.9108
# Epoch 49/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.0973 - accuracy: 0.9700 - val_loss: 0.2896 - val_accuracy: 0.9036
# Epoch 50/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.0897 - accuracy: 0.9661 - val_loss: 0.3181 - val_accuracy: 0.9181

# %%
def create_charts2(cnn, cnn_model):
    ## DEFINE ##
    ## Define 1:  train & validation loss
    train_loss = cnn_model.history['loss']
    val_loss = cnn_model.history['val_loss']
    
    ## Define 2: train & validation AUC
    train_auc_name = list(cnn_model.history.keys())[3]
    val_auc_name = list(cnn_model.history.keys())[1]
    train_auc = cnn_model.history[train_auc_name]
    val_auc = cnn_model.history[val_auc_name]
    
    ## Define 3: y_pred & y_true
    y_true = test_generator2.classes
    #print(y_true)
    Y_pred = cnn.predict_generator(test_generator2, steps = len(test_generator2))
    y_pred = (Y_pred > 0.5).T[0]
    #print(y_pred)
    y_pred_prob = Y_pred.T[0]
    #print(y_pred_prob)
    
    ## PLOT ##
    fig = plt.figure(figsize=(13, 10))
    
    ## PLOT 1: TRAIN VS. VALIDATION LOSS 
    plt.subplot(2,2,1)
    plt.title("Training vs. Validation Loss")
    plt.plot(train_loss, label='training loss')
    plt.plot(val_loss, label='validation loss')
    plt.xlabel("Number of Epochs", size=14)
    plt.legend()

    ## PLOT 2: TRAIN VS. VALIDATION AUC
    plt.subplot(2,2,2)
    plt.title("Training vs. Validation AUC Score")
    plt.plot(train_auc, label='training auc')
    plt.plot(val_auc, label='validation auc')
    plt.xlabel("Number of Epochs", size=14)
    plt.legend()
    
    ## PLOT 3: CONFUSION MATRIX
    plt.subplot(2,2,3)
      # Set up the labels for in the confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    names = ['True Negatives', 'False Positives', 'False Negatives', 'True Positives']
    counts = ['{0:0.0f}'.format(value) for value in cm.flatten()]
    percentages = ['{0:.2%}'.format(value) for value in cm.flatten()/np.sum(cm)]
    labels = [f'{v1}\n{v2}' for v1, v2 in zip(names, percentages)]
    labels = np.asarray(labels).reshape(2,2)
    ticklabels = ['Normal', 'Abnormal']

      # Create confusion matrix as heatmap
    sns.set(font_scale = 1.4)
    ax = sns.heatmap(cm, annot=labels, fmt='', cmap='Oranges', xticklabels=ticklabels, yticklabels=ticklabels )
    plt.xticks(size=12)
    plt.yticks(size=12)
    plt.title("Confusion Matrix") #plt.title("Confusion Matrix\n", fontsize=10)
    plt.xlabel("Predicted", size=14)
    plt.ylabel("Actual", size=14) 
    #plt.savefig('cm.png', transparent=True) 
    
    ## PLOT 4: ROC CURVE
    plt.subplot(2,2,4)
    fpr, tpr, thresholds = roc_curve(y_true, y_pred_prob)
    auc = roc_auc_score(y_true, y_pred_prob)
    plt.title('ROC Curve')
    plt.plot([0, 1], [0, 1], 'k--', label = "Random (AUC = 50%)")
    plt.plot(fpr, tpr, label='CNN (AUC = {:.2f}%)'.format(auc*100))
    plt.xlabel('False Positive Rate', size=14)
    plt.ylabel('True Positive Rate', size=14)
    plt.legend(loc='best')
    #plt.savefig('roc.png', bbox_inches='tight', pad_inches=1)
    
    ## END PLOTS
    plt.tight_layout()
    ;
    
    ## Summary Statistics
    TN, FP, FN, TP = cm.ravel() # cm[0,0], cm[0, 1], cm[1, 0], cm[1, 1]
    accuracy = (TP + TN) / np.sum(cm) # % positive out of all predicted positives
    precision = TP / (TP+FP) # % positive out of all predicted positives
    recall =  TP / (TP+FN) # % positive out of all supposed to be positives
    specificity = TN / (TN+FP) # % negative out of all supposed to be negatives
    f1 = 2*precision*recall / (precision + recall)
    stats_summary = '[Summary Statistics]\nAccuracy = {:.2%} | Precision = {:.2%} | Recall = {:.2%} | Specificity = {:.2%} | F1 Score = {:.2%}'.format(accuracy, precision, recall, specificity, f1)
    print(stats_summary)

# %%
create_charts2(cnn2, cnn_model2)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1976: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# [Summary Statistics]
# Accuracy = 64.82% | Precision = 67.88% | Recall = 60.93% | Specificity = 69.00% | F1 Score = 64.22%

# %% [markdown]
# **Normal Kernel Initializer**

# %%
## Set file paths to image files

train_path3 = "/content/drive/MyDrive/NewDB/Training set"
test_path3 = "/content/drive/MyDrive/NewDB/Test set"

## Set up hyperparameters that will be used later
hyper_dimension3 = 128
hyper_batch_size3 = 32
hyper_channels3 = 3
hyper_mode3= 'rgb'

## Generate batches of image data (train, validation, and test) with data augmentation
train_datagen3 = ImageDataGenerator(rescale=1.0/255.0, 
                                   shear_range = 0.2,
                                   zoom_range = 0.2, 
                                   horizontal_flip = True )

test_datagen3 = ImageDataGenerator(rescale=1.0/255.0) 

train_generator3 = train_datagen3.flow_from_directory(directory = train_path3, 
                                                    target_size = (hyper_dimension3, hyper_dimension3),
                                                    batch_size = hyper_batch_size3, 
                                                    color_mode = hyper_mode3,
                                                    class_mode = 'binary', 
                                                    seed = 42)

test_generator3 = test_datagen3.flow_from_directory(directory = test_path3, 
                                                 target_size = (hyper_dimension3, hyper_dimension3),
                                                 batch_size = hyper_batch_size3, 
                                                 class_mode = 'binary',
                                                 color_mode = hyper_mode3,
                                                 shuffle=False,
                                                 seed = 42)

test_generator3.reset()
# Out:
# Found 1656 images belonging to 2 classes.
# Found 415 images belonging to 2 classes.

# %%
cnn3 = Sequential()
cnn3.add(InputLayer(input_shape=(hyper_dimension3, hyper_dimension3, hyper_channels3)))

cnn3.add(Conv2D(filters=16, kernel_size=3, activation='relu',kernel_initializer='normal'))
cnn3.add(MaxPooling2D(pool_size=(2,2)))

cnn3.add(Conv2D(filters=32, kernel_size=3, activation='relu',kernel_initializer='normal'))
cnn3.add(MaxPooling2D(pool_size=(2,2)))

cnn3.add(Conv2D(filters=64, kernel_size=3, activation='relu',kernel_initializer='normal'))
cnn3.add(MaxPooling2D(pool_size=(2,2)))

cnn3.add(Flatten())

cnn3.add(Dense(activation='relu', units=128))
cnn3.add(Dense(activation='sigmoid', units=1))

cnn3.summary()

cnn3.compile(optimizer= 'adam', loss='binary_crossentropy', metrics=['accuracy'])
cnn_model3 = cnn3.fit_generator(train_generator3, 
                              steps_per_epoch = len(train_generator3), 
                              epochs = 50, 
                              validation_data = test_generator3,
                              validation_steps = len(test_generator3)
                              )
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 126, 126, 16)      448
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 63, 63, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 61, 61, 32)        4640
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 28, 28, 64)        18496
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 12544)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               1605760
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 1,629,473
# Trainable params: 1,629,473
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 52/52 [==============================] - 57s 1s/step - loss: 0.6843 - accuracy: 0.5618 - val_loss: 0.4889 - val_accuracy: 0.7759
# Epoch 2/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.5314 - accuracy: 0.7195 - val_loss: 0.3691 - val_accuracy: 0.8434
# Epoch 3/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.4508 - accuracy: 0.8004 - val_loss: 0.3716 - val_accuracy: 0.8265
# Epoch 4/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.3990 - accuracy: 0.8095 - val_loss: 0.3069 - val_accuracy: 0.8795
# Epoch 5/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.3579 - accuracy: 0.8375 - val_loss: 0.3148 - val_accuracy: 0.8843
# Epoch 6/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.3080 - accuracy: 0.8735 - val_loss: 0.3422 - val_accuracy: 0.8602
# Epoch 7/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.3281 - accuracy: 0.8655 - val_loss: 0.2955 - val_accuracy: 0.8892
# Epoch 8/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.2818 - accuracy: 0.8846 - val_loss: 0.2613 - val_accuracy: 0.8916
# Epoch 9/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.2536 - accuracy: 0.8941 - val_loss: 0.2794 - val_accuracy: 0.8916
# Epoch 10/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.2648 - accuracy: 0.8864 - val_loss: 0.3004 - val_accuracy: 0.8819
# Epoch 11/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.2651 - accuracy: 0.8977 - val_loss: 0.3025 - val_accuracy: 0.8964
# Epoch 12/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.2250 - accuracy: 0.9062 - val_loss: 0.3536 - val_accuracy: 0.8602
# Epoch 13/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.2229 - accuracy: 0.8997 - val_loss: 0.2823 - val_accuracy: 0.8916
# Epoch 14/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.2097 - accuracy: 0.9146 - val_loss: 0.2662 - val_accuracy: 0.9036
# Epoch 15/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.1991 - accuracy: 0.9189 - val_loss: 0.2691 - val_accuracy: 0.9108
# Epoch 16/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.2019 - accuracy: 0.9247 - val_loss: 0.2341 - val_accuracy: 0.9133
# Epoch 17/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.2025 - accuracy: 0.9112 - val_loss: 0.3044 - val_accuracy: 0.9036
# Epoch 18/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.1659 - accuracy: 0.9484 - val_loss: 0.2676 - val_accuracy: 0.9036
# Epoch 19/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.2020 - accuracy: 0.9092 - val_loss: 0.2308 - val_accuracy: 0.9181
# Epoch 20/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.2015 - accuracy: 0.9167 - val_loss: 0.2298 - val_accuracy: 0.9277
# Epoch 21/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.1739 - accuracy: 0.9358 - val_loss: 0.2365 - val_accuracy: 0.9253
# Epoch 22/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.1618 - accuracy: 0.9402 - val_loss: 0.2079 - val_accuracy: 0.9157
# Epoch 23/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.1595 - accuracy: 0.9390 - val_loss: 0.2238 - val_accuracy: 0.9229
# Epoch 24/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.1579 - accuracy: 0.9311 - val_loss: 0.2417 - val_accuracy: 0.9349
# Epoch 25/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.1409 - accuracy: 0.9409 - val_loss: 0.2264 - val_accuracy: 0.9277
# Epoch 26/50
# 52/52 [==============================] - 55s 1s/step - loss: 0.1572 - accuracy: 0.9338 - val_loss: 0.2598 - val_accuracy: 0.9205
# Epoch 27/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.1550 - accuracy: 0.9352 - val_loss: 0.2565 - val_accuracy: 0.9301
# Epoch 28/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.1352 - accuracy: 0.9460 - val_loss: 0.2294 - val_accuracy: 0.9301
# Epoch 29/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.1475 - accuracy: 0.9443 - val_loss: 0.2263 - val_accuracy: 0.9301
# Epoch 30/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.1494 - accuracy: 0.9369 - val_loss: 0.2536 - val_accuracy: 0.9205
# Epoch 31/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.1341 - accuracy: 0.9449 - val_loss: 0.2263 - val_accuracy: 0.9205
# Epoch 32/50
# 52/52 [==============================] - 57s 1s/step - loss: 0.1336 - accuracy: 0.9465 - val_loss: 0.2305 - val_accuracy: 0.9253
# Epoch 33/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.1010 - accuracy: 0.9617 - val_loss: 0.2845 - val_accuracy: 0.9181
# Epoch 34/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.1265 - accuracy: 0.9433 - val_loss: 0.2431 - val_accuracy: 0.9157
# Epoch 35/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.1182 - accuracy: 0.9475 - val_loss: 0.2256 - val_accuracy: 0.9373
# Epoch 36/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.0936 - accuracy: 0.9576 - val_loss: 0.2290 - val_accuracy: 0.9253
# Epoch 37/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.0956 - accuracy: 0.9640 - val_loss: 0.2721 - val_accuracy: 0.8892
# Epoch 38/50
# 52/52 [==============================] - 55s 1s/step - loss: 0.1027 - accuracy: 0.9596 - val_loss: 0.2167 - val_accuracy: 0.9446
# Epoch 39/50
# 52/52 [==============================] - 55s 1s/step - loss: 0.0845 - accuracy: 0.9629 - val_loss: 0.2793 - val_accuracy: 0.9253
# Epoch 40/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.0968 - accuracy: 0.9630 - val_loss: 0.2525 - val_accuracy: 0.9398
# Epoch 41/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.0929 - accuracy: 0.9607 - val_loss: 0.2769 - val_accuracy: 0.9205
# Epoch 42/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.0685 - accuracy: 0.9702 - val_loss: 0.2954 - val_accuracy: 0.9253
# Epoch 43/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.0908 - accuracy: 0.9622 - val_loss: 0.3079 - val_accuracy: 0.9108
# Epoch 44/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.0864 - accuracy: 0.9685 - val_loss: 0.2712 - val_accuracy: 0.9157
# Epoch 45/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.1141 - accuracy: 0.9557 - val_loss: 0.2610 - val_accuracy: 0.9229
# Epoch 46/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.0714 - accuracy: 0.9747 - val_loss: 0.2599 - val_accuracy: 0.9373
# Epoch 47/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.0734 - accuracy: 0.9739 - val_loss: 0.2997 - val_accuracy: 0.9157
# Epoch 48/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.0680 - accuracy: 0.9755 - val_loss: 0.3002 - val_accuracy: 0.9181
# Epoch 49/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.0531 - accuracy: 0.9761 - val_loss: 0.3288 - val_accuracy: 0.9253
# Epoch 50/50
# 52/52 [==============================] - 55s 1s/step - loss: 0.0565 - accuracy: 0.9795 - val_loss: 0.3179 - val_accuracy: 0.9301

# %%
def create_charts3(cnn, cnn_model):
    ## DEFINE ##
    ## Define 1:  train & validation loss
    train_loss = cnn_model.history['loss']
    val_loss = cnn_model.history['val_loss']
    
    ## Define 2: train & validation AUC
    train_auc_name = list(cnn_model.history.keys())[3]
    val_auc_name = list(cnn_model.history.keys())[1]
    train_auc = cnn_model.history[train_auc_name]
    val_auc = cnn_model.history[val_auc_name]
    
    ## Define 3: y_pred & y_true
    y_true = test_generator3.classes
    #print(y_true)
    Y_pred = cnn.predict_generator(test_generator3, steps = len(test_generator3))
    y_pred = (Y_pred > 0.5).T[0]
    #print(y_pred)
    y_pred_prob = Y_pred.T[0]
    #print(y_pred_prob)
    
    ## PLOT ##
    fig = plt.figure(figsize=(13, 10))
    
    ## PLOT 1: TRAIN VS. VALIDATION LOSS 
    plt.subplot(2,2,1)
    plt.title("Training vs. Validation Loss")
    plt.plot(train_loss, label='training loss')
    plt.plot(val_loss, label='validation loss')
    plt.xlabel("Number of Epochs", size=14)
    plt.legend()

    ## PLOT 2: TRAIN VS. VALIDATION AUC
    plt.subplot(2,2,2)
    plt.title("Training vs. Validation AUC Score")
    plt.plot(train_auc, label='training auc')
    plt.plot(val_auc, label='validation auc')
    plt.xlabel("Number of Epochs", size=14)
    plt.legend()
    
    ## PLOT 3: CONFUSION MATRIX
    plt.subplot(2,2,3)
      # Set up the labels for in the confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    names = ['True Negatives', 'False Positives', 'False Negatives', 'True Positives']
    counts = ['{0:0.0f}'.format(value) for value in cm.flatten()]
    percentages = ['{0:.2%}'.format(value) for value in cm.flatten()/np.sum(cm)]
    labels = [f'{v1}\n{v2}' for v1, v2 in zip(names, percentages)]
    labels = np.asarray(labels).reshape(2,2)
    ticklabels = ['Normal', 'Abnormal']

      # Create confusion matrix as heatmap
    sns.set(font_scale = 1.4)
    ax = sns.heatmap(cm, annot=labels, fmt='', cmap='Oranges', xticklabels=ticklabels, yticklabels=ticklabels )
    plt.xticks(size=12)
    plt.yticks(size=12)
    plt.title("Confusion Matrix") #plt.title("Confusion Matrix\n", fontsize=10)
    plt.xlabel("Predicted", size=14)
    plt.ylabel("Actual", size=14) 
    #plt.savefig('cm.png', transparent=True) 
    
    ## PLOT 4: ROC CURVE
    plt.subplot(2,2,4)
    fpr, tpr, thresholds = roc_curve(y_true, y_pred_prob)
    auc = roc_auc_score(y_true, y_pred_prob)
    plt.title('ROC Curve')
    plt.plot([0, 1], [0, 1], 'k--', label = "Random (AUC = 50%)")
    plt.plot(fpr, tpr, label='CNN (AUC = {:.2f}%)'.format(auc*100))
    plt.xlabel('False Positive Rate', size=14)
    plt.ylabel('True Positive Rate', size=14)
    plt.legend(loc='best')
    #plt.savefig('roc.png', bbox_inches='tight', pad_inches=1)
    
    ## END PLOTS
    plt.tight_layout()
    ;
    
    ## Summary Statistics
    TN, FP, FN, TP = cm.ravel() # cm[0,0], cm[0, 1], cm[1, 0], cm[1, 1]
    accuracy = (TP + TN) / np.sum(cm) # % positive out of all predicted positives
    precision = TP / (TP+FP) # % positive out of all predicted positives
    recall =  TP / (TP+FN) # % positive out of all supposed to be positives
    specificity = TN / (TN+FP) # % negative out of all supposed to be negatives
    f1 = 2*precision*recall / (precision + recall)
    stats_summary = '[Summary Statistics]\nAccuracy = {:.2%} | Precision = {:.2%} | Recall = {:.2%} | Specificity = {:.2%} | F1 Score = {:.2%}'.format(accuracy, precision, recall, specificity, f1)
    print(stats_summary)

# %%
create_charts3(cnn3, cnn_model3)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1976: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# [Summary Statistics]
# Accuracy = 63.61% | Precision = 64.95% | Recall = 64.65% | Specificity = 62.50% | F1 Score = 64.80%

# %% [markdown]
# **Golorot_normal Initializer**

# %%
## Set file paths to image files

train_path4 = "/content/drive/MyDrive/NewDB/Training set"
test_path4 = "/content/drive/MyDrive/NewDB/Test set"

## Set up hyperparameters that will be used later
hyper_dimension4 = 128
hyper_batch_size4 = 32
hyper_channels4 = 3
hyper_mode4= 'rgb'

## Generate batches of image data (train, validation, and test) with data augmentation
train_datagen4 = ImageDataGenerator(rescale=1.0/255.0, 
                                   shear_range = 0.2,
                                   zoom_range = 0.2, 
                                   horizontal_flip = True )

test_datagen4 = ImageDataGenerator(rescale=1.0/255.0) 

train_generator4 = train_datagen4.flow_from_directory(directory = train_path4, 
                                                    target_size = (hyper_dimension4, hyper_dimension4),
                                                    batch_size = hyper_batch_size4, 
                                                    color_mode = hyper_mode4,
                                                    class_mode = 'binary', 
                                                    seed = 42)

test_generator4 = test_datagen4.flow_from_directory(directory = test_path4, 
                                                 target_size = (hyper_dimension4, hyper_dimension4),
                                                 batch_size = hyper_batch_size4, 
                                                 class_mode = 'binary',
                                                 color_mode = hyper_mode4,
                                                 shuffle=False,
                                                 seed = 42)

test_generator4.reset()
# Out:
# Found 1656 images belonging to 2 classes.
# Found 415 images belonging to 2 classes.

# %%
cnn4 = Sequential()
cnn4.add(InputLayer(input_shape=(hyper_dimension4, hyper_dimension4, hyper_channels4)))

cnn4.add(Conv2D(filters=16, kernel_size=3, activation='relu',kernel_initializer='glorot_normal'))
cnn4.add(MaxPooling2D(pool_size=(2,2)))

cnn4.add(Conv2D(filters=32, kernel_size=3, activation='relu',kernel_initializer='glorot_normal'))
cnn4.add(MaxPooling2D(pool_size=(2,2)))

cnn4.add(Conv2D(filters=64, kernel_size=3, activation='relu',kernel_initializer='glorot_normal'))
cnn4.add(MaxPooling2D(pool_size=(2,2)))

cnn4.add(Flatten())

cnn4.add(Dense(activation='relu', units=128))
cnn4.add(Dense(activation='sigmoid', units=1))

cnn4.summary()

cnn4.compile(optimizer= 'Adadelta', loss='binary_crossentropy', metrics=['accuracy'])
cnn_model4 = cnn4.fit_generator(train_generator4, 
                              steps_per_epoch = len(train_generator4), 
                              epochs = 50, 
                              validation_data = test_generator4,
                              validation_steps = len(test_generator4)
                              )
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 126, 126, 16)      448
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 63, 63, 16)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 61, 61, 32)        4640
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 28, 28, 64)        18496
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 12544)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               1605760
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 1,629,473
# Trainable params: 1,629,473
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 52/52 [==============================] - 57s 1s/step - loss: 0.7006 - accuracy: 0.3981 - val_loss: 0.6952 - val_accuracy: 0.4530
# Epoch 2/50
# 52/52 [==============================] - 55s 1s/step - loss: 0.6967 - accuracy: 0.3948 - val_loss: 0.6920 - val_accuracy: 0.5831
# Epoch 3/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.6927 - accuracy: 0.5118 - val_loss: 0.6894 - val_accuracy: 0.5301
# Epoch 4/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.6900 - accuracy: 0.5361 - val_loss: 0.6876 - val_accuracy: 0.5277
# Epoch 5/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.6874 - accuracy: 0.5368 - val_loss: 0.6863 - val_accuracy: 0.5253
# Epoch 6/50
# 52/52 [==============================] - 56s 1s/step - loss: 0.6866 - accuracy: 0.5440 - val_loss: 0.6853 - val_accuracy: 0.5566
# Epoch 7/50
# 52/52 [==============================] - 55s 1s/step - loss: 0.6862 - accuracy: 0.5776 - val_loss: 0.6842 - val_accuracy: 0.5542
# Epoch 8/50
# 52/52 [==============================] - 55s 1s/step - loss: 0.6850 - accuracy: 0.5808 - val_loss: 0.6834 - val_accuracy: 0.5566
# Epoch 9/50
# 52/52 [==============================] - 55s 1s/step - loss: 0.
50
# 52/52 [==============================] - 55s 1s/step - loss: 0.6454 - accuracy: 0.7054 - val_loss: 0.6592 - val_accuracy: 0.7012
# Epoch 40/50
# 52/52 [==============================] - 55s 1s/step - loss: 0.6517 - accuracy: 0.6871 - val_loss: 0.6585 - val_accuracy: 0.6867
# Epoch 41/50
# 52/52 [==============================] - 55s 1s/step - loss: 0.6460 - accuracy: 0.7008 - val_loss: 0.6577 - val_accuracy: 0.6916
# Epoch 42/50
# 52/52 [==============================] - 55s 1s/step - loss: 0.6422 - accuracy: 0.6979 - val_loss: 0.6568 - val_accuracy: 0.6988
# Epoch 43/50
# 52/52 [==============================] - 55s 1s/step - loss: 0.6461 - accuracy: 0.6934 - val_loss: 0.6560 - val_accuracy: 0.6940
# Epoch 44/50
# 52/52 [==============================] - 55s 1s/step - loss: 0.6411 - accuracy: 0.7032 - val_loss: 0.6551 - val_accuracy: 0.7012
# Epoch 45/50
# 52/52 [==============================] - 55s 1s/step - loss: 0.6427 - accuracy: 0.6927 - val_loss: 0.6544 - val_accuracy: 0.7012
# Epoch 46/50
# 52/52 [==============================] - 55s 1s/step - loss: 0.6373 - accuracy: 0.6974 - val_loss: 0.6538 - val_accuracy: 0.6916
# Epoch 47/50
# 52/52 [==============================] - 55s 1s/step - loss: 0.6357 - accuracy: 0.7130 - val_loss: 0.6530 - val_accuracy: 0.6916
# Epoch 48/50
# 52/52 [==============================] - 55s 1s/step - loss: 0.6421 - accuracy: 0.6851 - val_loss: 0.6522 - val_accuracy: 0.6940
# Epoch 49/50
# 52/52 [==============================] - 55s 1s/step - loss: 0.6359 - accuracy: 0.7033 - val_loss: 0.6512 - val_accuracy: 0.6964
# Epoch 50/50
# 52/52 [==============================] - 55s 1s/step - loss: 0.6334 - accuracy: 0.6916 - val_loss: 0.6504 - val_accuracy: 0.7036

# %%
def create_charts4(cnn, cnn_model):
    ## DEFINE ##
    ## Define 1:  train & validation loss
    train_loss = cnn_model.history['loss']
    val_loss = cnn_model.history['val_loss']
    
    ## Define 2: train & validation AUC
    train_auc_name = list(cnn_model.history.keys())[3]
    val_auc_name = list(cnn_model.history.keys())[1]
    train_auc = cnn_model.history[train_auc_name]
    val_auc = cnn_model.history[val_auc_name]
    
    ## Define 3: y_pred & y_true
    y_true = test_generator4.classes
    #print(y_true)
    Y_pred = cnn.predict_generator(test_generator4, steps = len(test_generator4))
    y_pred = (Y_pred > 0.5).T[0]
    #print(y_pred)
    y_pred_prob = Y_pred.T[0]
    #print(y_pred_prob)
    
    ## PLOT ##
    fig = plt.figure(figsize=(13, 10))
    
    ## PLOT 1: TRAIN VS. VALIDATION LOSS 
    plt.subplot(2,2,1)
    plt.title("Training vs. Validation Loss")
    plt.plot(train_loss, label='training loss')
    plt.plot(val_loss, label='validation loss')
    plt.xlabel("Number of Epochs", size=14)
    plt.legend()

    ## PLOT 2: TRAIN VS. VALIDATION AUC
    plt.subplot(2,2,2)
    plt.title("Training vs. Validation AUC Score")
    plt.plot(train_auc, label='training auc')
    plt.plot(val_auc, label='validation auc')
    plt.xlabel("Number of Epochs", size=14)
    plt.legend()
    
    ## PLOT 3: CONFUSION MATRIX
    plt.subplot(2,2,3)
      # Set up the labels for in the confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    names = ['True Negatives', 'False Positives', 'False Negatives', 'True Positives']
    counts = ['{0:0.0f}'.format(value) for value in cm.flatten()]
    percentages = ['{0:.2%}'.format(value) for value in cm.flatten()/np.sum(cm)]
    labels = [f'{v1}\n{v2}' for v1, v2 in zip(names, percentages)]
    labels = np.asarray(labels).reshape(2,2)
    ticklabels = ['Normal', 'Abnormal']

      # Create confusion matrix as heatmap
    sns.set(font_scale = 1.4)
    ax = sns.heatmap(cm, annot=labels, fmt='', cmap='Oranges', xticklabels=ticklabels, yticklabels=ticklabels )
    plt.xticks(size=12)
    plt.yticks(size=12)
    plt.title("Confusion Matrix") #plt.title("Confusion Matrix\n", fontsize=10)
    plt.xlabel("Predicted", size=14)
    plt.ylabel("Actual", size=14) 
    #plt.savefig('cm.png', transparent=True) 
    
    ## PLOT 4: ROC CURVE
    plt.subplot(2,2,4)
    fpr, tpr, thresholds = roc_curve(y_true, y_pred_prob)
    auc = roc_auc_score(y_true, y_pred_prob)
    plt.title('ROC Curve')
    plt.plot([0, 1], [0, 1], 'k--', label = "Random (AUC = 50%)")
    plt.plot(fpr, tpr, label='CNN (AUC = {:.2f}%)'.format(auc*100))
    plt.xlabel('False Positive Rate', size=14)
    plt.ylabel('True Positive Rate', size=14)
    plt.legend(loc='best')
    #plt.savefig('roc.png', bbox_inches='tight', pad_inches=1)
    
    ## END PLOTS
    plt.tight_layout()
    ;
    
    ## Summary Statistics
    TN, FP, FN, TP = cm.ravel() # cm[0,0], cm[0, 1], cm[1, 0], cm[1, 1]
    accuracy = (TP + TN) / np.sum(cm) # % positive out of all predicted positives
    precision = TP / (TP+FP) # % positive out of all predicted positives
    recall =  TP / (TP+FN) # % positive out of all supposed to be positives
    specificity = TN / (TN+FP) # % negative out of all supposed to be negatives
    f1 = 2*precision*recall / (precision + recall)
    stats_summary = '[Summary Statistics]\nAccuracy = {:.2%} | Precision = {:.2%} | Recall = {:.2%} | Specificity = {:.2%} | F1 Score = {:.2%}'.format(accuracy, precision, recall, specificity, f1)
    print(stats_summary)

# %%
create_charts4(cnn4, cnn_model4)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1976: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# [Summary Statistics]
# Accuracy = 51.08% | Precision = 55.08% | Recall = 30.23% | Specificity = 73.50% | F1 Score = 39.04%

# %% [markdown]
# **Zero kernel Initializer**

# %%
## Set file paths to image files

train_path5 = "/content/drive/MyDrive/NewDB/Training set"
test_path5 = "/content/drive/MyDrive/NewDB/Test set"

## Set up hyperparameters that will be used later
hyper_dimension5 = 128
hyper_batch_size5 = 32
hyper_channels5 = 3
hyper_mode5= 'rgb'

## Generate batches of image data (train, validation, and test) with data augmentation
train_datagen5 = ImageDataGenerator(rescale=1.0/255.0, 
                                   shear_range = 0.2,
                                   zoom_range = 0.2, 
                                   horizontal_flip = True )

test_datagen5 = ImageDataGenerator(rescale=1.0/255.0) 

train_generator5 = train_datagen5.flow_from_directory(directory = train_path5, 
                                                    target_size = (hyper_dimension5, hyper_dimension5),
                                                    batch_size = hyper_batch_size5, 
                                                    color_mode = hyper_mode5,
                                                    class_mode = 'binary', 
                                                    seed = 42)

test_generator5 = test_datagen5.flow_from_directory(directory = test_path5, 
                                                 target_size = (hyper_dimension5, hyper_dimension5),
                                                 batch_size = hyper_batch_size5, 
                                                 class_mode = 'binary',
                                                 color_mode = hyper_mode5,
                                                 shuffle=False,
                                                 seed = 42)

test_generator5.reset()
# Out:
# Found 1656 images belonging to 2 classes.
# Found 415 images belonging to 2 classes.

# %%
cnn5 = Sequential()
cnn5.add(InputLayer(input_shape=(hyper_dimension5, hyper_dimension5, hyper_channels5)))

cnn5.add(Conv2D(filters=16, kernel_size=3, activation='relu',kernel_initializer='zero'))
cnn5.add(MaxPooling2D(pool_size=(2,2)))

cnn5.add(Conv2D(filters=32, kernel_size=3, activation='relu',kernel_initializer='zero'))
cnn5.add(MaxPooling2D(pool_size=(2,2)))

cnn5.add(Conv2D(filters=64, kernel_size=3, activation='relu',kernel_initializer='zero'))
cnn5.add(MaxPooling2D(pool_size=(2,2)))

cnn5.add(Flatten())

cnn5.add(Dense(activation='relu', units=128))
cnn5.add(Dense(activation='sigmoid', units=1))

cnn5.summary()

cnn5.compile(optimizer= 'Adagrad', loss='binary_crossentropy', metrics=['accuracy'])
cnn_model5 = cnn5.fit_generator(train_generator5, 
                              steps_per_epoch = len(train_generator5), 
                              epochs = 50, 
                              validation_data = test_generator5,
                              validation_steps = len(test_generator5)
                              )
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None,
classes
    #print(y_true)
    Y_pred = cnn.predict_generator(test_generator5, steps = len(test_generator5))
    y_pred = (Y_pred > 0.5).T[0]
    #print(y_pred)
    y_pred_prob = Y_pred.T[0]
    #print(y_pred_prob)
    
    ## PLOT ##
    fig = plt.figure(figsize=(13, 10))
    
    ## PLOT 1: TRAIN VS. VALIDATION LOSS 
    plt.subplot(2,2,1)
    plt.title("Training vs. Validation Loss")
    plt.plot(train_loss, label='training loss')
    plt.plot(val_loss, label='validation loss')
    plt.xlabel("Number of Epochs", size=14)
    plt.legend()

    ## PLOT 2: TRAIN VS. VALIDATION AUC
    plt.subplot(2,2,2)
    plt.title("Training vs. Validation AUC Score")
    plt.plot(train_auc, label='training auc')
    plt.plot(val_auc, label='validation auc')
    plt.xlabel("Number of Epochs", size=14)
    plt.legend()
    
    ## PLOT 3: CONFUSION MATRIX
    plt.subplot(2,2,3)
      # Set up the labels for in the confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    names = ['True Negatives', 'False Positives', 'False Negatives', 'True Positives']
    counts = ['{0:0.0f}'.format(value) for value in cm.flatten()]
    percentages = ['{0:.2%}'.format(value) for value in cm.flatten()/np.sum(cm)]
    labels = [f'{v1}\n{v2}' for v1, v2 in zip(names, percentages)]
    labels = np.asarray(labels).reshape(2,2)
    ticklabels = ['Normal', 'Abnormal']

      # Create confusion matrix as heatmap
    sns.set(font_scale = 1.4)
    ax = sns.heatmap(cm, annot=labels, fmt='', cmap='Oranges', xticklabels=ticklabels, yticklabels=ticklabels )
    plt.xticks(size=12)
    plt.yticks(size=12)
    plt.title("Confusion Matrix") #plt.title("Confusion Matrix\n", fontsize=10)
    plt.xlabel("Predicted", size=14)
    plt.ylabel("Actual", size=14) 
    #plt.savefig('cm.png', transparent=True) 
    
    ## PLOT 4: ROC CURVE
    plt.subplot(2,2,4)
    fpr, tpr, thresholds = roc_curve(y_true, y_pred_prob)
    auc = roc_auc_score(y_true, y_pred_prob)
    plt.title('ROC Curve')
    plt.plot([0, 1], [0, 1], 'k--', label = "Random (AUC = 50%)")
    plt.plot(fpr, tpr, label='CNN (AUC = {:.2f}%)'.format(auc*100))
    plt.xlabel('False Positive Rate', size=14)
    plt.ylabel('True Positive Rate', size=14)
    plt.legend(loc='best')
    #plt.savefig('roc.png', bbox_inches='tight', pad_inches=1)
    
    ## END PLOTS
    plt.tight_layout()
    ;
    
    ## Summary Statistics
    TN, FP, FN, TP = cm.ravel() # cm[0,0], cm[0, 1], cm[1, 0], cm[1, 1]
    accuracy = (TP + TN) / np.sum(cm) # % positive out of all predicted positives
    precision = TP / (TP+FP) # % positive out of all predicted positives
    recall =  TP / (TP+FN) # % positive out of all supposed to be positives
    specificity = TN / (TN+FP) # % negative out of all supposed to be negatives
    f1 = 2*precision*recall / (precision + recall)
    stats_summary = '[Summary Statistics]\nAccuracy = {:.2%} | Precision = {:.2%} | Recall = {:.2%} | Specificity = {:.2%} | F1 Score = {:.2%}'.format(accuracy, precision, recall, specificity, f1)
    print(stats_summary)

# %%
create_charts5(cnn5, cnn_model5)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1976: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# [Summary Statistics]
# Accuracy = 51.81% | Precision = 51.81% | Recall = 100.00% | Specificity = 0.00% | F1 Score = 68.25%

# %% [markdown]
# **Superimposing Accuracy and Loss graphs for different Kernel Initializers**

# %%
EPOCHS=50

record_arr1 = np.array([cnn_model1.history['loss'][0], cnn_model1.history['accuracy'][0]])
for i in range(1, EPOCHS):
    new_row1 = np.array([cnn_model1.history['loss'][i], cnn_model1.history['accuracy'][i]])
    record_arr1 = np.row_stack((record_arr1, new_row1))
    
record_df1 = pd.DataFrame(record_arr1, columns=["loss", "acc"])

record_arr2 = np.array([cnn_model2.history['loss'][0], cnn_model2.history['accuracy'][0]])
for i in range(1, EPOCHS):
    new_row2 = np.array([cnn_model2.history['loss'][i], cnn_model2.history['accuracy'][i]])
    record_arr2 = np.row_stack((record_arr2, new_row2))
    
record_df2 = pd.DataFrame(record_arr2, columns=["loss", "acc"])

record_arr3 = np.array([cnn_model3.history['loss'][0], cnn_model3.history['accuracy'][0]])
for i in range(1, EPOCHS):
    new_row3 = np.array([cnn_model3.history['loss'][i], cnn_model3.history['accuracy'][i]])
    record_arr3 = np.row_stack((record_arr3, new_row3))
    
record_df3 = pd.DataFrame(record_arr3, columns=["loss", "acc"])

record_arr4 = np.array([cnn_model4.history['loss'][0], cnn_model4.history['accuracy'][0]])
for i in range(1, EPOCHS):
    new_row4 = np.array([cnn_model4.history['loss'][i], cnn_model4.history['accuracy'][i]])
    record_arr4 = np.row_stack((record_arr4, new_row4))
    
record_df4 = pd.DataFrame(record_arr4, columns=["loss", "acc"])

record_arr5 = np.array([cnn_model5.history['loss'][0], cnn_model5.history['accuracy'][0]])
for i in range(1, EPOCHS):
    new_row5 = np.array([cnn_model5.history['loss'][i], cnn_model5.history['accuracy'][i]])
    record_arr5 = np.row_stack((record_arr5, new_row5))
    
record_df5 = pd.DataFrame(record_arr4, columns=["loss", "acc"])

#print curve
fig = plt.figure(figsize=(13, 10))
plt.subplot(2,2,1)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss of conducted experiments vs. Epochs')
plt.plot(np.arange(0, EPOCHS), record_df1["loss"], label='glorot_uniform')
plt.plot(np.arange(0, EPOCHS), record_df2["loss"], label='uniform')
plt.plot(np.arange(0, EPOCHS), record_df3["loss"], label='normal')
#plt.plot(np.arange(0, EPOCHS), record_df4["loss"], label='glorot_normal')
plt.plot(np.arange(0, EPOCHS), record_df5["loss"], label='zero')
plt.legend()
# fig.saveplot(path1+'Loss')
plt.subplot(2,2,2)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training Accuracy of conducted experiments vs. Epochs')
plt.plot(np.arange(0, EPOCHS), record_df1["acc"], label='glorot_uniform')
plt.plot(np.arange(0, EPOCHS), record_df2["acc"], label='uniform')
plt.plot(np.arange(0, EPOCHS), record_df3["acc"], label='normal')
#plt.plot(np.arange(0, EPOCHS), record_df4["acc"], label='glorot_normal')
plt.plot(np.arange(0, EPOCHS), record_df5["acc"], label='zero')
plt.legend()
plt.tight_layout()

plt.show()

save_path='/content/drive/MyDrive/New Images'
fig.savefig(save_path+'New-27_Initializer')
