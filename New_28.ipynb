# %% [markdown]
# <a href="https://colab.research.google.com/github/rish4/NewColonoscopy/blob/main/New_28.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc
import keras
import tensorflow as tf
from keras import backend as K
from keras import metrics
from keras.regularizers import l2
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, InputLayer, Activation
from keras.preprocessing.image import ImageDataGenerator
from keras.metrics import AUC
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix
from keras import models
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
import numpy as np
from keras.preprocessing import image
from IPython.display import display
from PIL import Image

# %% [markdown]
# **Kernel size-3**

# %%
## Set file paths to image files

train_path1 = "/content/drive/MyDrive/NewDB/Training set"
test_path1 = "/content/drive/MyDrive/NewDB/Test set"

## Set up hyperparameters that will be used later
hyper_dimension1 = 128
hyper_batch_size1 = 32
hyper_channels1 = 3
hyper_mode1 = 'rgb'

## Generate batches of image data (train, validation, and test) with data augmentation
train_datagen1 = ImageDataGenerator(rescale=1.0/255.0, 
                                   shear_range = 0.2,
                                   zoom_range = 0.2, 
                                   horizontal_flip = True )

test_datagen1 = ImageDataGenerator(rescale=1.0/255.0) 

train_generator1 = train_datagen1.flow_from_directory(directory = train_path1, 
                                                    target_size = (hyper_dimension1, hyper_dimension1),
                                                    batch_size = hyper_batch_size1, 
                                                    color_mode = hyper_mode1,
                                                    class_mode = 'binary', 
                                                    seed = 42)

test_generator1 = test_datagen1.flow_from_directory(directory = test_path1, 
                                                 target_size = (hyper_dimension1, hyper_dimension1),
                                                 batch_size = hyper_batch_size1, 
                                                 class_mode = 'binary',
                                                 color_mode = hyper_mode1,
                                                 shuffle=False,
                                                 seed = 42)

test_generator1.reset()
# Out:
# Found 1656 images belonging to 2 classes.
# Found 415 images belonging to 2 classes.

# %%
cnn1 = Sequential()
cnn1.add(InputLayer(input_shape=(hyper_dimension1, hyper_dimension1, hyper_channels1)))

cnn1.add(Conv2D(filters=16, kernel_size=3, activation='relu'))
cnn1.add(MaxPooling2D(pool_size=(2,2)))

cnn1.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn1.add(MaxPooling2D(pool_size=(2,2)))

cnn1.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
cnn1.add(MaxPooling2D(pool_size=(2,2)))

cnn1.add(Flatten())

cnn1.add(Dense(activation='relu', units=128))
cnn1.add(Dense(activation='sigmoid', units=1))

cnn1.summary()

cnn1.compile(optimizer= 'adam', loss='binary_crossentropy', metrics=['accuracy'])
cnn_model1 = cnn1.fit_generator(train_generator1, 
                              steps_per_epoch = len(train_generator1), 
                              epochs = 50, 
                              validation_data = test_generator1,
                              validation_steps = len(test_generator1)
                              )
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 126, 126, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 61, 61, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 12544)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1605760
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 1,629,473
# Trainable params: 1,629,473
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 52/52 [==============================] - 517s 10s/step - loss: 0.6957 - accuracy: 0.5366 - val_loss: 0.6322 - val_accuracy: 0.6723
# Epoch 2/50
# 52/52 [==============================] - 65s 1s/step - loss: 0.5380 - accuracy: 0.7307 - val_loss: 0.3687 - val_accuracy: 0.8651
# Epoch 3/50
# 52/52 [==============================] - 62s 1s/step - loss: 0.4049 - accuracy: 0.8138 - val_loss: 0.3543 - val_accuracy: 0.8819
# Epoch 4/50
# 52/52 [==============================] - 61s 1s/step - loss: 0.3885 - accuracy: 0.8366 - val_loss: 0.3041 - val_accuracy: 0.8964
# Epoch 5/50
# 52/52 [==============================] - 61s 1s/step - loss: 0.3262 - accuracy: 0.8617 - val_loss: 0.3101 - val_accuracy: 0.8699
# Epoch 6/50
# 52/52 [==============================] - 62s 1s/step - loss: 0.3032 - accuracy: 0.8730 - val_loss: 0.3078 - val_accuracy: 0.8723
# Epoch 7/50
# 52/52 [==============================] - 61s 1s/step - loss: 0.3081 - accuracy: 0.8720 - val_loss: 0.2835 - val_accuracy: 0.8843
# Epoch 8/50
# 52/52 [==============================] - 61s 1s/step - loss: 0.2426 - accuracy: 0.9052 - val_loss: 0.2743 - val_accuracy: 0.8964
# Epoch 9/50
# 52/52 [==============================] - 61s 1s/step - loss: 0.2506 - accuracy: 0.9007 - val_loss: 0.2884 - val_accuracy: 0.9084
# Epoch 10/50
# 52/52 [==============================] - 62s 1s/step - loss: 0.2664 - accuracy: 0.8911 - val_loss: 0.2477 - val_accuracy: 0.9229
# Epoch 11/50
# 52/52 [==============================] - 61s 1s/step - loss: 0.2384 - accuracy: 0.9052 - val_loss: 0.3225 - val_accuracy: 0.8747
# Epoch 12/50
# 52/52 [==============================] - 65s 1s/step - loss: 0.2171 - accuracy: 0.9092 - val_loss: 0.3284 - val_accuracy: 0.8627
# Epoch 13/50
# 52/52 [==============================] - 62s 1s/step - loss: 0.2026 - accuracy: 0.9131 - val_loss: 0.2406 - val_accuracy: 0.9108
# Epoch 14/50
# 52/52 [==============================] - 61s 1s/step - loss: 0.2081 - accuracy: 0.9188 - val_loss: 0.2696 - val_accuracy: 0.8940
# Epoch 15/50
# 52/52 [==============================] - 61s 1s/step - loss: 0.1905 - accuracy: 0.9258 - val_loss: 0.2684 - val_accuracy: 0.8916
# Epoch 16/50
# 52/52 [==============================] - 61s 1s/step - loss: 0.1867 - accuracy: 0.9297 - val_loss: 0.2728 - val_accuracy: 0.8819
# Epoch 17/50
# 52/52 [==============================] - 61s 1s/step - loss: 0.2019 - accuracy: 0.9108 - val_loss: 0.2756 - val_accuracy: 0.8940
# Epoch 18/50
# 52/52 [==============================] - 61s 1s/step - loss: 0.1670 - accuracy: 0.9358 - val_loss: 0.2861 - val_accuracy: 0.8964
# Epoch 19/50
# 52/52 [==============================] - 61s 1s/step - loss: 0.1633 - accuracy: 0.9298 - val_loss: 0.2395 - val_accuracy: 0.9036
# Epoch 20/50
# 52/52 [==============================] - 61s 1s/step - loss: 0.1743 - accuracy: 0.9376 - val_loss: 0.2345 - val_accuracy: 0.9108
# Epoch 21/50
# 52/52 [==============================] - 61s 1s/step - loss: 0.1495 - accuracy: 0.9467 - val_loss: 0.3143 - val_accuracy: 0.8843
# Epoch 22/50
# 52/52 [==============================] - 60s 1s/step - loss: 0.1598 - accuracy: 0.9376 - val_loss: 0.2136 - val_accuracy: 0.9133
# Epoch 23/50
# 52/52 [==============================] - 61s 1s/step - loss: 0.1241 - accuracy: 0.9597 - val_loss: 0.2039 - val_accuracy: 0.9108
# Epoch 24/50
# 52/52 [==============================] - 61s 1s/step - loss: 0.1540 - accuracy: 0.9373 - val_loss: 0.2417 - val_accuracy: 0.9060
# Epoch 25/50
# 52/52 [==============================] - 60s 1s/step - loss: 0.1181 - accuracy: 0.9543 - val_loss: 0.2567 - val_accuracy: 0.8940
# Epoch 26/50
# 52/52 [==============================] - 60s 1s/step - loss: 0.1466 - accuracy: 0.9415 - val_loss: 0.2164 - val_accuracy: 0.9157
# Epoch 27/50
# 52/52 [==============================] - 61s 1s/step - loss: 0.1149 - accuracy: 0.9565 - val_loss: 0.2472 - val_accuracy: 0.9108
# Epoch 28/50
# 52/52 [==============================] - 61s 1s/step - loss: 0.1183 - accuracy: 0.9588 - val_loss: 0.2138 - val_accuracy: 0.9133
# Epoch 29/50
# 52/52 [==============================] - 61s 1s/step - loss: 0.1217 - accuracy: 0.9507 - val_loss: 0.2713 - val_accuracy: 0.8916
# Epoch 30/50
# 52/52 [==============================] - 62s 1s/step - loss: 0.1518 - accuracy: 0.9332 - val_loss: 0.2692 - val_accuracy: 0.9036
# Epoch 31/50
# 52/52 [==============================] - 62s 1s/step - loss: 0.1113 - accuracy: 0.9506 - val_loss: 0.2412 - val_accuracy: 0.9108
# Epoch 32/50
# 52/52 [==============================] - 62s 1s/step - loss: 0.1043 - accuracy: 0.9615 - val_loss: 0.2501 - val_accuracy: 0.8988
# Epoch 33/50
# 52/52 [==============================] - 61s 1s/step - loss: 0.0962 - accuracy: 0.9670 - val_loss: 0.3021 - val_accuracy: 0.9036
# Epoch 34/50
# 52/52 [==============================] - 61s 1s/step - loss: 0.0922 - accuracy: 0.9707 - val_loss: 0.2884 - val_accuracy: 0.9036
# Epoch 35/50
# 52/52 [==============================] - 61s 1s/step - loss: 0.1029 - accuracy: 0.9635 - val_loss: 0.2763 - val_accuracy: 0.9084
# Epoch 36/50
# 52/52 [==============================] - 60s 1s/step - loss: 0.0702 - accuracy: 0.9705 - val_loss: 0.2399 - val_accuracy: 0.9181
# Epoch 37/50
# 52/52 [==============================] - 60s 1s/step - loss: 0.0713 - accuracy: 0.9711 - val_loss: 0.3184 - val_accuracy: 0.8940
# Epoch 38/50
# 52/52 [==============================] - 60s 1s/step - loss: 0.0879 - accuracy: 0.9676 - val_loss: 0.2389 - val_accuracy: 0.9253
# Epoch 39/50
# 52/52 [==============================] - 60s 1s/step - loss: 0.0507 - accuracy: 0.9806 - val_loss: 0.2857 - val_accuracy: 0.9181
# Epoch 40/50
# 52/52 [==============================] - 61s 1s/step - loss: 0.0590 - accuracy: 0.9830 - val_loss: 0.2568 - val_accuracy: 0.9084
# Epoch 41/50
# 52/52 [==============================] - 60s 1s/step - loss: 0.0773 - accuracy: 0.9699 - val_loss: 0.3061 - val_accuracy: 0.9036
# Epoch 42/50
# 52/52 [==============================] - 60s 1s/step - loss: 0.0556 - accuracy: 0.9843 - val_loss: 0.2175 - val_accuracy: 0.9157
# Epoch 43/50
# 52/52 [==============================] - 61s 1s/step - loss: 0.0626 - accuracy: 0.9746 - val_loss: 0.2863 - val_accuracy: 0.9229
# Epoch 44/50
# 52/52 [==============================] - 61s 1s/step - loss: 0.0774 - accuracy: 0.9753 - val_loss: 0.2438 - val_accuracy: 0.9157
# Epoch 45/50
# 52/52 [==============================] - 61s 1s/step - loss: 0.0457 - accuracy: 0.9843 - val_loss: 0.2614 - val_accuracy: 0.9253
# Epoch 46/50
# 52/52 [==============================] - 61s 1s/step - loss: 0.0644 - accuracy: 0.9804 - val_loss: 0.2958 - val_accuracy: 0.9181
# Epoch 47/50
# 52/52 [==============================] - 61s 1s/step - loss: 0.0724 - accuracy: 0.9731 - val_loss: 0.3243 - val_accuracy: 0.9012
# Epoch 48/50
# 52/52 [==============================] - 60s 1s/step - loss: 0.0627 - accuracy: 0.9757 - val_loss: 0.2311 - val_accuracy: 0.9229
# Epoch 49/50
# 52/52 [==============================] - 61s 1s/step - loss: 0.0455 - accuracy: 0.9805 - val_loss: 0.2344 - val_accuracy: 0.9325
# Epoch 50/50
# 52/52 [==============================] - 61s 1s/step - loss: 0.0422 - accuracy: 0.9822 - val_loss: 0.3164 - val_accuracy: 0.9157

# %%
def create_charts1(cnn, cnn_model):
    ## DEFINE ##
    ## Define 1:  train & validation loss
    train_loss = cnn_model.history['loss']
    val_loss = cnn_model.history['val_loss']
    
    ## Define 2: train & validation AUC
    train_auc_name = list(cnn_model.history.keys())[3]
    val_auc_name = list(cnn_model.history.keys())[1]
    train_auc = cnn_model.history[train_auc_name]
    val_auc = cnn_model.history[val_auc_name]
    
    ## Define 3: y_pred & y_true
    y_true = test_generator1.classes
    #print(y_true)
    Y_pred = cnn.predict_generator(test_generator1, steps = len(test_generator1))
    y_pred = (Y_pred > 0.5).T[0]
    #print(y_pred)
    y_pred_prob = Y_pred.T[0]
    #print(y_pred_prob)
    
    ## PLOT ##
    fig = plt.figure(figsize=(13, 10))
    
    ## PLOT 1: TRAIN VS. VALIDATION LOSS 
    plt.subplot(2,2,1)
    plt.title("Training vs. Validation Loss")
    plt.plot(train_loss, label='training loss')
    plt.plot(val_loss, label='validation loss')
    plt.xlabel("Number of Epochs", size=14)
    plt.legend()

    ## PLOT 2: TRAIN VS. VALIDATION AUC
    plt.subplot(2,2,2)
    plt.title("Training vs. Validation AUC Score")
    plt.plot(train_auc, label='training auc')
    plt.plot(val_auc, label='validation auc')
    plt.xlabel("Number of Epochs", size=14)
    plt.legend()
    
    ## PLOT 3: CONFUSION MATRIX
    plt.subplot(2,2,3)
      # Set up the labels for in the confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    names = ['True Negatives', 'False Positives', 'False Negatives', 'True Positives']
    counts = ['{0:0.0f}'.format(value) for value in cm.flatten()]
    percentages = ['{0:.2%}'.format(value) for value in cm.flatten()/np.sum(cm)]
    labels = [f'{v1}\n{v2}' for v1, v2 in zip(names, percentages)]
    labels = np.asarray(labels).reshape(2,2)
    ticklabels = ['Normal', 'Abnormal']

      # Create confusion matrix as heatmap
    sns.set(font_scale = 1.4)
    ax = sns.heatmap(cm, annot=labels, fmt='', cmap='Oranges', xticklabels=ticklabels, yticklabels=ticklabels )
    plt.xticks(size=12)
    plt.yticks(size=12)
    plt.title("Confusion Matrix") #plt.title("Confusion Matrix\n", fontsize=10)
    plt.xlabel("Predicted", size=14)
    plt.ylabel("Actual", size=14) 
    #plt.savefig('cm.png', transparent=True) 
    
    ## PLOT 4: ROC CURVE
    plt.subplot(2,2,4)
    fpr, tpr, thresholds = roc_curve(y_true, y_pred_prob)
    auc = roc_auc_score(y_true, y_pred_prob)
    plt.title('ROC Curve')
    plt.plot([0, 1], [0, 1], 'k--', label = "Random (AUC = 50%)")
    plt.plot(fpr, tpr, label='CNN (AUC = {:.2f}%)'.format(auc*100))
    plt.xlabel('False Positive Rate', size=14)
    plt.ylabel('True Positive Rate', size=14)
    plt.legend(loc='best')
    #plt.savefig('roc.png', bbox_inches='tight', pad_inches=1)
    
    ## END PLOTS
    plt.tight_layout()
    ;
    
    ## Summary Statistics
    TN, FP, FN, TP = cm.ravel() # cm[0,0], cm[0, 1], cm[1, 0], cm[1, 1]
    accuracy = (TP + TN) / np.sum(cm) # % positive out of all predicted positives
    precision = TP / (TP+FP) # % positive out of all predicted positives
    recall =  TP / (TP+FN) # % positive out of all supposed to be positives
    specificity = TN / (TN+FP) # % negative out of all supposed to be negatives
    f1 = 2*precision*recall / (precision + recall)
    stats_summary = '[Summary Statistics]\nAccuracy = {:.2%} | Precision = {:.2%} | Recall = {:.2%} | Specificity = {:.2%} | F1 Score = {:.2%}'.format(accuracy, precision, recall, specificity, f1)
    print(stats_summary)

# %%
create_charts1(cnn1, cnn_model1)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1976: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# [Summary Statistics]
# Accuracy = 62.65% | Precision = 65.00% | Recall = 60.47% | Specificity = 65.00% | F1 Score = 62.65%

# %% [markdown]
# **Kernel size-5**

# %%
## Set file paths to image files

train_path2 = "/content/drive/MyDrive/NewDB/Training set"
test_path2 = "/content/drive/MyDrive/NewDB/Test set"

## Set up hyperparameters that will be used later
hyper_dimension2 = 128
hyper_batch_size2 = 32
hyper_channels2 = 3
hyper_mode2 = 'rgb'

## Generate batches of image data (train, validation, and test) with data augmentation
train_datagen2 = ImageDataGenerator(rescale=1.0/255.0, 
                                   shear_range = 0.2,
                                   zoom_range = 0.2, 
                                   horizontal_flip = True )

test_datagen2 = ImageDataGenerator(rescale=1.0/255.0) 

train_generator2 = train_datagen2.flow_from_directory(directory = train_path2, 
                                                    target_size = (hyper_dimension2, hyper_dimension2),
                                                    batch_size = hyper_batch_size2, 
                                                    color_mode = hyper_mode2,
                                                    class_mode = 'binary', 
                                                    seed = 42)

test_generator2 = test_datagen2.flow_from_directory(directory = test_path2, 
                                                 target_size = (hyper_dimension2, hyper_dimension2),
                                                 batch_size = hyper_batch_size2, 
                                                 class_mode = 'binary',
                                                 color_mode = hyper_mode2,
                                                 shuffle=False,
                                                 seed = 42)

test_generator2.reset()
# Out:
# Found 1656 images belonging to 2 classes.
# Found 415 images belonging to 2 classes.

# %%
cnn2 = Sequential()
cnn2.add(InputLayer(input_shape=(hyper_dimension2, hyper_dimension2, hyper_channels2)))

cnn2.add(Conv2D(filters=16, kernel_size=5, activation='relu'))
cnn2.add(MaxPooling2D(pool_size=(2,2)))

cnn2.add(Conv2D(filters=32, kernel_size=5, activation='relu'))
cnn2.add(MaxPooling2D(pool_size=(2,2)))

cnn2.add(Conv2D(filters=64, kernel_size=5, activation='relu'))
cnn2.add(MaxPooling2D(pool_size=(2,2)))

cnn2.add(Flatten())

cnn2.add(Dense(activation='relu', units=128))
cnn2.add(Dense(activation='sigmoid', units=1))

cnn2.summary()

cnn2.compile(optimizer= 'adam', loss='binary_crossentropy', metrics=['accuracy'])
cnn_model2 = cnn2.fit_generator(train_generator1, 
                              steps_per_epoch = len(train_generator2), 
                              epochs = 50, 
                              validation_data = test_generator2,
                              validation_steps = len(test_generator2)
                              )
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 124, 124, 16)      1216
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 58, 58, 32)        12832
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 29, 29, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 25, 25, 64)        51264
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 9216)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               1179776
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 1,245,217
# Trainable params: 1,245,217
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 52/52 [==============================] - 78s 1s/step - loss: 0.7039 - accuracy: 0.5658 - val_loss: 0.4439 - val_accuracy: 0.7807
# Epoch 2/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.5322 - accuracy: 0.7346 - val_loss: 0.4821 - val_accuracy: 0.7735
# Epoch 3/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.4637 - accuracy: 0.7660 - val_loss: 0.3925 - val_accuracy: 0.8096
# Epoch 4/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.4272 - accuracy: 0.7914 - val_loss: 0.3398 - val_accuracy: 0.8386
# Epoch 5/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.3922 - accuracy: 0.8213 - val_loss: 0.3075 - val_accuracy: 0.8819
# Epoch 6/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.3698 - accuracy: 0.8392 - val_loss: 0.3042 - val_accuracy: 0.8988
# Epoch 7/50
# 52/52 [==============================] - 76s 1s/step - loss: 0.3518 - accuracy: 0.8448 - val_loss: 0.2686 - val_accuracy: 0.9084
# Epoch 8/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.2868 - accuracy: 0.8816 - val_loss: 0.2918 - val_accuracy: 0.8723
# Epoch 9/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.2963 - accuracy: 0.8792 - val_loss: 0.3683 - val_accuracy: 0.8482
# Epoch 10/50
# 52/52 [==============================] - 76s 1s/step - loss: 0.3123 - accuracy: 0.8593 - val_loss: 0.2219 - val_accuracy: 0.9181
# Epoch 11/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.2756 - accuracy: 0.8826 - val_loss: 0.2883 - val_accuracy: 0.8892
# Epoch 12/50
# 52/52 [==============================] - 81s 2s/step - loss: 0.2386 - accuracy: 0.8963 - val_loss: 0.2680 - val_accuracy: 0.9036
# Epoch 13/50
# 52/52 [==============================] - 76s 1s/step - loss: 0.2553 - accuracy: 0.8962 - val_loss: 0.2541 - val_accuracy: 0.9060
# Epoch 14/50
# 52/52 [==============================] - 76s 1s/step - loss: 0.2250 - accuracy: 0.9082 - val_loss: 0.2727 - val_accuracy: 0.9012
# Epoch 15/50
# 52/52 [==============================] - 76s 1s/step - loss: 0.2132 - accuracy: 0.9124 - val_loss: 0.2458 - val_accuracy: 0.9157
# Epoch 16/50
# 52/52 [==============================] - 76s 1s/step - loss: 0.2175 - accuracy: 0.9163 - val_loss: 0.2586 - val_accuracy: 0.9036
# Epoch 17/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.2108 - accuracy: 0.9100 - val_loss: 0.2147 - val_accuracy: 0.9253
# Epoch 18/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.2260 - accuracy: 0.9128 - val_loss: 0.2858 - val_accuracy: 0.8843
# Epoch 19/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.1690 - accuracy: 0.9345 - val_loss: 0.2026 - val_accuracy: 0.9277
# Epoch 20/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.1966 - accuracy: 0.9164 - val_loss: 0.2282 - val_accuracy: 0.9157
# Epoch 21/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.1678 - accuracy: 0.9303 - val_loss: 0.2601 - val_accuracy: 0.9157
# Epoch 22/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.1503 - accuracy: 0.9510 - val_loss: 0.2332 - val_accuracy: 0.9301
# Epoch 23/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.1487 - accuracy: 0.9511 - val_loss: 0.2699 - val_accuracy: 0.9108
# Epoch 24/50
# 52/52 [==============================] - 76s 1s/step - loss: 0.1939 - accuracy: 0.9245 - val_loss: 0.2562 - val_accuracy: 0.9012
# Epoch 25/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.1529 - accuracy: 0.9387 - val_loss: 0.2220 - val_accuracy: 0.9060
# Epoch 26/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.1510 - accuracy: 0.9357 - val_loss: 0.2883 - val_accuracy: 0.8867
# Epoch 27/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.1355 - accuracy: 0.9424 - val_loss: 0.2266 - val_accuracy: 0.9181
# Epoch 28/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.1309 - accuracy: 0.9493 - val_loss: 0.2138 - val_accuracy: 0.9229
# Epoch 29/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.1318 - accuracy: 0.9457 - val_loss: 0.2779 - val_accuracy: 0.8988
# Epoch 30/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.1190 - accuracy: 0.9573 - val_loss: 0.2456 - val_accuracy: 0.9084
# Epoch 31/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.1301 - accuracy: 0.9446 - val_loss: 0.2761 - val_accuracy: 0.9012
# Epoch 32/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.1478 - accuracy: 0.9383 - val_loss: 0.2469 - val_accuracy: 0.9253
# Epoch 33/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.1067 - accuracy: 0.9570 - val_loss: 0.3230 - val_accuracy: 0.8578
# Epoch 34/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.1511 - accuracy: 0.9355 - val_loss: 0.2344 - val_accuracy: 0.9181
# Epoch 35/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.1092 - accuracy: 0.9530 - val_loss: 0.3507 - val_accuracy: 0.8747
# Epoch 36/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.1112 - accuracy: 0.9586 - val_loss: 0.2427 - val_accuracy: 0.9157
# Epoch 37/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.1110 - accuracy: 0.9576 - val_loss: 0.2992 - val_accuracy: 0.9133
# Epoch 38/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.0979 - accuracy: 0.9617 - val_loss: 0.2319 - val_accuracy: 0.9157
# Epoch 39/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.0869 - accuracy: 0.9644 - val_loss: 0.2653 - val_accuracy: 0.9084
# Epoch 40/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.0921 - accuracy: 0.9726 - val_loss: 0.2879 - val_accuracy: 0.8916
# Epoch 41/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.0751 - accuracy: 0.9771 - val_loss: 0.4185 - val_accuracy: 0.8771
# Epoch 42/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.1389 - accuracy: 0.9434 - val_loss: 0.2357 - val_accuracy: 0.9181
# Epoch 43/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.0716 - accuracy: 0.9780 - val_loss: 0.3771 - val_accuracy: 0.8675
# Epoch 44/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.0765 - accuracy: 0.9689 - val_loss: 0.2819 - val_accuracy: 0.9133
# Epoch 45/50
# 52/52 [==============================] - 78s 2s/step - loss: 0.0519 - accuracy: 0.9831 - val_loss: 0.2842 - val_accuracy: 0.9133
# Epoch 46/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.0754 - accuracy: 0.9672 - val_loss: 0.2384 - val_accuracy: 0.9277
# Epoch 47/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.0639 - accuracy: 0.9771 - val_loss: 0.3147 - val_accuracy: 0.9084
# Epoch 48/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.0775 - accuracy: 0.9681 - val_loss: 0.3010 - val_accuracy: 0.9084
# Epoch 49/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.0575 - accuracy: 0.9802 - val_loss: 0.2888 - val_accuracy: 0.9133
# Epoch 50/50
# 52/52 [==============================] - 77s 1s/step - loss: 0.0512 - accuracy: 0.9756 - val_loss: 0.4172 - val_accuracy: 0.8554

# %%
def create_charts2(cnn, cnn_model):
    ## DEFINE ##
    ## Define 1:  train & validation loss
    train_loss = cnn_model.history['loss']
    val_loss = cnn_model.history['val_loss']
    
    ## Define 2: train & validation AUC
    train_auc_name = list(cnn_model.history.keys())[3]
    val_auc_name = list(cnn_model.history.keys())[1]
    train_auc = cnn_model.history[train_auc_name]
    val_auc = cnn_model.history[val_auc_name]
    
    ## Define 3: y_pred & y_true
    y_true = test_generator2.classes
    #print(y_true)
    Y_pred = cnn.predict_generator(test_generator2, steps = len(test_generator2))
    y_pred = (Y_pred > 0.5).T[0]
    #print(y_pred)
    y_pred_prob = Y_pred.T[0]
    #print(y_pred_prob)
    
    ## PLOT ##
    fig = plt.figure(figsize=(13, 10))
    
    ## PLOT 1: TRAIN VS. VALIDATION LOSS 
    plt.subplot(2,2,1)
    plt.title("Training vs. Validation Loss")
    plt.plot(train_loss, label='training loss')
    plt.plot(val_loss, label='validation loss')
    plt.xlabel("Number of Epochs", size=14)
    plt.legend()

    ## PLOT 2: TRAIN VS. VALIDATION AUC
    plt.subplot(2,2,2)
    plt.title("Training vs. Validation AUC Score")
    plt.plot(train_auc, label='training auc')
    plt.plot(val_auc, label='validation auc')
    plt.xlabel("Number of Epochs", size=14)
    plt.legend()
    
    ## PLOT 3: CONFUSION MATRIX
    plt.subplot(2,2,3)
      # Set up the labels for in the confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    names = ['True Negatives', 'False Positives', 'False Negatives', 'True Positives']
    counts = ['{0:0.0f}'.format(value) for value in cm.flatten()]
    percentages = ['{0:.2%}'.format(value) for value in cm.flatten()/np.sum(cm)]
    labels = [f'{v1}\n{v2}' for v1, v2 in zip(names, percentages)]
    labels = np.asarray(labels).reshape(2,2)
    ticklabels = ['Normal', 'Abnormal']

      # Create confusion matrix as heatmap
    sns.set(font_scale = 1.4)
    ax = sns.heatmap(cm, annot=labels, fmt='', cmap='Oranges', xticklabels=ticklabels, yticklabels=ticklabels )
    plt.xticks(size=12)
    plt.yticks(size=12)
    plt.title("Confusion Matrix") #plt.title("Confusion Matrix\n", fontsize=10)
    plt.xlabel("Predicted", size=14)
    plt.ylabel("Actual", size=14) 
    #plt.savefig('cm.png', transparent=True) 
    
    ## PLOT 4: ROC CURVE
    plt.subplot(2,2,4)
    fpr, tpr, thresholds = roc_curve(y_true, y_pred_prob)
    auc = roc_auc_score(y_true, y_pred_prob)
    plt.title('ROC Curve')
    plt.plot([0, 1], [0, 1], 'k--', label = "Random (AUC = 50%)")
    plt.plot(fpr, tpr, label='CNN (AUC = {:.2f}%)'.format(auc*100))
    plt.xlabel('False Positive Rate', size=14)
    plt.ylabel('True Positive Rate', size=14)
    plt.legend(loc='best')
    #plt.savefig('roc.png', bbox_inches='tight', pad_inches=1)
    
    ## END PLOTS
    plt.tight_layout()
    ;
    
    ## Summary Statistics
    TN, FP, FN, TP = cm.ravel() # cm[0,0], cm[0, 1], cm[1, 0], cm[1, 1]
    accuracy = (TP + TN) / np.sum(cm) # % positive out of all predicted positives
    precision = TP / (TP+FP) # % positive out of all predicted positives
    recall =  TP / (TP+FN) # % positive out of all supposed to be positives
    specificity = TN / (TN+FP) # % negative out of all supposed to be negatives
    f1 = 2*precision*recall / (precision + recall)
    stats_summary = '[Summary Statistics]\nAccuracy = {:.2%} | Precision = {:.2%} | Recall = {:.2%} | Specificity = {:.2%} | F1 Score = {:.2%}'.format(accuracy, precision, recall, specificity, f1)
    print(stats_summary)

# %%
create_charts2(cnn2, cnn_model2)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1976: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# [Summary Statistics]
# Accuracy = 64.82% | Precision = 68.85% | Recall = 58.60% | Specificity = 71.50% | F1 Score = 63.32%

# %% [markdown]
# **Kernel size 7**

# %%
## Set file paths to image files

train_path3 = "/content/drive/MyDrive/NewDB/Training set"
test_path3 = "/content/drive/MyDrive/NewDB/Test set"

## Set up hyperparameters that will be used later
hyper_dimension3 = 128
hyper_batch_size3 = 32
hyper_channels3 = 3
hyper_mode3= 'rgb'

## Generate batches of image data (train, validation, and test) with data augmentation
train_datagen3 = ImageDataGenerator(rescale=1.0/255.0, 
                                   shear_range = 0.2,
                                   zoom_range = 0.2, 
                                   horizontal_flip = True )

test_datagen3 = ImageDataGenerator(rescale=1.0/255.0) 

train_generator3 = train_datagen3.flow_from_directory(directory = train_path3, 
                                                    target_size = (hyper_dimension3, hyper_dimension3),
                                                    batch_size = hyper_batch_size3, 
                                                    color_mode = hyper_mode3,
                                                    class_mode = 'binary', 
                                                    seed = 42)

test_generator3 = test_datagen3.flow_from_directory(directory = test_path3, 
                                                 target_size = (hyper_dimension3, hyper_dimension3),
                                                 batch_size = hyper_batch_size3, 
                                                 class_mode = 'binary',
                                                 color_mode = hyper_mode3,
                                                 shuffle=False,
                                                 seed = 42)

test_generator3.reset()
# Out:
# Found 1656 images belonging to 2 classes.
# Found 415 images belonging to 2 classes.

# %%
cnn3 = Sequential()
cnn3.add(InputLayer(input_shape=(hyper_dimension3, hyper_dimension3, hyper_channels3)))

cnn3.add(Conv2D(filters=16, kernel_size=7, activation='relu'))
cnn3.add(MaxPooling2D(pool_size=(2,2)))

cnn3.add(Conv2D(filters=32, kernel_size=7, activation='relu'))
cnn3.add(MaxPooling2D(pool_size=(2,2)))

cnn3.add(Conv2D(filters=64, kernel_size=7, activation='relu'))
cnn3.add(MaxPooling2D(pool_size=(2,2)))

cnn3.add(Flatten())

cnn3.add(Dense(activation='relu', units=128))
cnn3.add(Dense(activation='sigmoid', units=1))

cnn3.summary()

cnn3.compile(optimizer= 'adam', loss='binary_crossentropy', metrics=['accuracy'])
cnn_model3 = cnn3.fit_generator(train_generator3, 
                              steps_per_epoch = len(train_generator3), 
                              epochs = 50, 
                              validation_data = test_generator3,
                              validation_steps = len(test_generator3)
                              )
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 122, 122, 16)      2368
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 61, 61, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 55, 55, 32)        25120
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 27, 27, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 21, 21, 64)        100416
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 6400)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               819328
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 947,361
# Trainable params: 947,361
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 52/52 [==============================] - 100s 2s/step - loss: 0.7268 - accuracy: 0.4954 - val_loss: 0.6255 - val_accuracy: 0.6843
# Epoch 2/50
# 52/52 [==============================] - 98s 2s/step - loss: 0.6248 - accuracy: 0.6527 - val_loss: 0.5622 - val_accuracy: 0.6916
# Epoch 3/50
# 52/52 [==============================] - 99s 2s/step - loss: 0.4999 - accuracy: 0.7480 - val_loss: 0.3787 - val_accuracy: 0.8241
# Epoch 4/50
# 52/52 [==============================] - 99s 2s/step - loss: 0.4183 - accuracy: 0.8067 - val_loss: 0.3408 - val_accuracy: 0.8386
# Epoch 5/50
# 52/52 [==============================] - 99s 2s/step - loss: 0.3909 - accuracy: 0.8368 - val_loss: 0.3588 - val_accuracy: 0.8506
# Epoch 6/50
# 52/52 [==============================] - 99s 2s/step - loss: 0.3889 - accuracy: 0.8332 - val_loss: 0.3463 - val_accuracy: 0.8602
# Epoch 7/50
# 52/52 [==============================] - 98s 2s/step - loss: 0.3883 - accuracy: 0.8353 - val_loss: 0.2760 - val_accuracy: 0.8723
# Epoch 8/50
# 52/52 [==============================] - 98s 2s/step - loss: 0.3318 - accuracy: 0.8618 - val_loss: 0.2931 - val_accuracy: 0.8723
# Epoch 9/50
# 52/52 [==============================] - 98s 2s/step - loss: 0.3284 - accuracy: 0.8572 - val_loss: 0.2849 - val_accuracy: 0.9036
# Epoch 10/50
# 52/52 [==============================] - 98s 2s/step - loss: 0.3329 - accuracy: 0.8642 - val_loss: 0.2699 - val_accuracy: 0.8964
# Epoch 11/50
# 52/52 [==============================] - 98s 2s/step - loss: 0.2889 - accuracy: 0.8783 - val_loss: 0.3388 - val_accuracy: 0.8723
# Epoch 12/50
# 52/52 [==============================] - 98s 2s/step - loss: 0.2631 - accuracy: 0.8923 - val_loss: 0.2956 - val_accuracy: 0.8916
# Epoch 13/50
# 52/52 [==============================] - 98s 2s/step - loss: 0.2682 - accuracy: 0.8964 - val_loss: 0.2494 - val_accuracy: 0.9084
# Epoch 14/50
# 52/52 [==============================] - 98s 2s/step - loss: 0.2347 - accuracy: 0.9090 - val_loss: 0.2848 - val_accuracy: 0.8916
# Epoch 15/50
# 52/52 [==============================] - 98s 2s/step - loss: 0.2494 - accuracy: 0.9032 - val_loss: 0.3312 - val_accuracy: 0.8892
# Epoch 16/50
# 52/52 [==============================] - 98s 2s/step - loss: 0.2198 - accuracy: 0.9174 - val_loss: 0.2356 - val_accuracy: 0.8940
# Epoch 17/50
# 52/52 [==============================] - 98s 2s/step - loss: 0.2330 - accuracy: 0.9019 - val_loss: 0.2620 - val_accuracy: 0.9036
# Epoch 18/50
# 52/52 [==============================] - 99s 2s/step - loss: 0.2166 - accuracy: 0.9119 - val_loss: 0.2597 - val_accuracy: 0.9060
# Epoch 19/50
# 52/52 [==============================] - 99s 2s/step - loss: 0.2023 - accuracy: 0.9135 - val_loss: 0.2954 - val_accuracy: 0.8795
# Epoch 20/50
# 52/52 [==============================] - 98s 2s/step - loss: 0.2270 - accuracy: 0.9091 - val_loss: 0.2188 - val_accuracy: 0.9229
# Epoch 21/50
# 52/52 [==============================] - 101s 2s/step - loss: 0.1833 - accuracy: 0.9279 - val_loss: 0.2766 - val_accuracy: 0.8867
# Epoch 22/50
# 52/52 [==============================] - 97s 2s/step - loss: 0.1821 - accuracy: 0.9248 - val_loss: 0.2829 - val_accuracy: 0.9036
# Epoch 23/50
# 52/52 [==============================] - 97s 2s/step - loss: 0.1646 - accuracy: 0.9442 - val_loss: 0.2561 - val_accuracy: 0.9108
# Epoch 24/50
# 52/52 [==============================] - 97s 2s/step - loss: 0.1580 - accuracy: 0.9413 - val_loss: 0.1951 - val_accuracy: 0.9373
# Epoch 25/50
# 52/52 [==============================] - 97s 2s/step - loss: 0.1408 - accuracy: 0.9390 - val_loss: 0.2686 - val_accuracy: 0.9181
# Epoch 26/50
# 52/52 [==============================] - 97s 2s/step - loss: 0.1483 - accuracy: 0.9435 - val_loss: 0.2520 - val_accuracy: 0.9229
# Epoch 27/50
# 52/52 [==============================] - 97s 2s/step - loss: 0.1273 - accuracy: 0.9532 - val_loss: 0.2444 - val_accuracy: 0.9157
# Epoch 28/50
# 52/52 [==============================] - 97s 2s/step - loss: 0.1019 - accuracy: 0.9650 - val_loss: 0.2227 - val_accuracy: 0.9301
# Epoch 29/50
# 52/52 [==============================] - 98s 2s/step - loss: 0.1118 - accuracy: 0.9511 - val_loss: 0.2389 - val_accuracy: 0.9205
# Epoch 30/50
# 52/52 [==============================] - 98s 2s/step - loss: 0.1334 - accuracy: 0.9504 - val_loss: 0.2845 - val_accuracy: 0.9205
# Epoch 31/50
# 52/52 [==============================] - 98s 2s/step - loss: 0.1428 - accuracy: 0.9459 - val_loss: 0.2474 - val_accuracy: 0.9398
# Epoch 32/50
# 52/52 [==============================] - 98s 2s/step - loss: 0.0968 - accuracy: 0.9632 - val_loss: 0.2958 - val_accuracy: 0.9253
# Epoch 33/50
# 52/52 [==============================] - 98s 2s/step - loss: 0.0944 - accuracy: 0.9660 - val_loss: 0.3043 - val_accuracy: 0.9253
# Epoch 34/50
# 52/52 [==============================] - 98s 2s/step - loss: 0.1169 - accuracy: 0.9561 - val_loss: 0.2422 - val_accuracy: 0.9301
# Epoch 35/50
# 52/52 [==============================] - 97s 2s/step - loss: 0.1275 - accuracy: 0.9427 - val_loss: 0.2529 - val_accuracy: 0.9181
# Epoch 36/50
# 52/52 [==============================] - 98s 2s/step - loss: 0.1031 - accuracy: 0.9631 - val_loss: 0.2954 - val_accuracy: 0.9133
# Epoch 37/50
# 52/52 [==============================] - 98s 2s/step - loss: 0.0807 - accuracy: 0.9728 - val_loss: 0.3874 - val_accuracy: 0.8964
# Epoch 38/50
# 52/52 [==============================] - 97s 2s/step - loss: 0.1240 - accuracy: 0.9584 - val_loss: 0.2628 - val_accuracy: 0.9181
# Epoch 39/50
# 52/52 [==============================] - 97s 2s/step - loss: 0.0695 - accuracy: 0.9750 - val_loss: 0.2961 - val_accuracy: 0.9301
# Epoch 40/50
# 52/52 [==============================] - 98s 2s/step - loss: 0.0786 - accuracy: 0.9742 - val_loss: 0.3606 - val_accuracy: 0.8964
# Epoch 41/50
# 52/52 [==============================] - 98s 2s/step - loss: 0.1287 - accuracy: 0.9487 - val_loss: 0.3322 - val_accuracy: 0.8940
# Epoch 42/50
# 52/52 [==============================] - 98s 2s/step - loss: 0.0735 - accuracy: 0.9711 - val_loss: 0.3246 - val_accuracy: 0.9229
# Epoch 43/50
# 52/52 [==============================] - 98s 2s/step - loss: 0.1005 - accuracy: 0.9661 - val_loss: 0.3228 - val_accuracy: 0.9229
# Epoch 44/50
# 52/52 [==============================] - 98s 2s/step - loss: 0.0790 - accuracy: 0.9648 - val_loss: 0.3212 - val_accuracy: 0.9012
# Epoch 45/50
# 52/52 [==============================] - 98s 2s/step - loss: 0.1053 - accuracy: 0.9570 - val_loss: 0.3375 - val_accuracy: 0.8988
# Epoch 46/50
# 52/52 [==============================] - 98s 2s/step - loss: 0.0596 - accuracy: 0.9801 - val_loss: 0.3804 - val_accuracy: 0.9133
# Epoch 47/50
# 52/52 [==============================] - 97s 2s/step - loss: 0.0464 - accuracy: 0.9850 - val_loss: 0.3429 - val_accuracy: 0.9133
# Epoch 48/50
# 52/52 [==============================] - 97s 2s/step - loss: 0.1212 - accuracy: 0.9562 - val_loss: 0.5223 - val_accuracy: 0.8675
# Epoch 49/50
# 52/52 [==============================] - 97s 2s/step - loss: 0.0997 - accuracy: 0.9635 - val_loss: 0.3130 - val_accuracy: 0.9205
# Epoch 50/50
# 52/52 [==============================] - 97s 2s/step - loss: 0.1142 - accuracy: 0.9572 - val_loss: 0.3111 - val_accuracy: 0.9084

# %%
def create_charts3(cnn, cnn_model):
    ## DEFINE ##
    ## Define 1:  train & validation loss
    train_loss = cnn_model.history['loss']
    val_loss = cnn_model.history['val_loss']
    
    ## Define 2: train & validation AUC
    train_auc_name = list(cnn_model.history.keys())[3]
    val_auc_name = list(cnn_model.history.keys())[1]
    train_auc = cnn_model.history[train_auc_name]
    val_auc = cnn_model.history[val_auc_name]
    
    ## Define 3: y_pred & y_true
    y_true = test_generator3.classes
    #print(y_true)
    Y_pred = cnn.predict_generator(test_generator3, steps = len(test_generator3))
    y_pred = (Y_pred > 0.5).T[0]
    #print(y_pred)
    y_pred_prob = Y_pred.T[0]
    #print(y_pred_prob)
    
    ## PLOT ##
    fig = plt.figure(figsize=(13, 10))
    
    ## PLOT 1: TRAIN VS. VALIDATION LOSS 
    plt.subplot(2,2,1)
    plt.title("Training vs. Validation Loss")
    plt.plot(train_loss, label='training loss')
    plt.plot(val_loss, label='validation loss')
    plt.xlabel("Number of Epochs", size=14)
    plt.legend()

    ## PLOT 2: TRAIN VS. VALIDATION AUC
    plt.subplot(2,2,2)
    plt.title("Training vs. Validation AUC Score")
    plt.plot(train_auc, label='training auc')
    plt.plot(val_auc, label='validation auc')
    plt.xlabel("Number of Epochs", size=14)
    plt.legend()
    
    ## PLOT 3: CONFUSION MATRIX
    plt.subplot(2,2,3)
      # Set up the labels for in the confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    names = ['True Negatives', 'False Positives', 'False Negatives', 'True Positives']
    counts = ['{0:0.0f}'.format(value) for value in cm.flatten()]
    percentages = ['{0:.2%}'.format(value) for value in cm.flatten()/np.sum(cm)]
    labels = [f'{v1}\n{v2}' for v1, v2 in zip(names, percentages)]
    labels = np.asarray(labels).reshape(2,2)
    ticklabels = ['Normal', 'Abnormal']

      # Create confusion matrix as heatmap
    sns.set(font_scale = 1.4)
    ax = sns.heatmap(cm, annot=labels, fmt='', cmap='Oranges', xticklabels=ticklabels, yticklabels=ticklabels )
    plt.xticks(size=12)
    plt.yticks(size=12)
    plt.title("Confusion Matrix") #plt.title("Confusion Matrix\n", fontsize=10)
    plt.xlabel("Predicted", size=14)
    plt.ylabel("Actual", size=14) 
    #plt.savefig('cm.png', transparent=True) 
    
    ## PLOT 4: ROC CURVE
    plt.subplot(2,2,4)
    fpr, tpr, thresholds = roc_curve(y_true, y_pred_prob)
    auc = roc_auc_score(y_true, y_pred_prob)
    plt.title('ROC Curve')
    plt.plot([0, 1], [0, 1], 'k--', label = "Random (AUC = 50%)")
    plt.plot(fpr, tpr, label='CNN (AUC = {:.2f}%)'.format(auc*100))
    plt.xlabel('False Positive Rate', size=14)
    plt.ylabel('True Positive Rate', size=14)
    plt.legend(loc='best')
    #plt.savefig('roc.png', bbox_inches='tight', pad_inches=1)
    
    ## END PLOTS
    plt.tight_layout()
    ;
    
    ## Summary Statistics
    TN, FP, FN, TP = cm.ravel() # cm[0,0], cm[0, 1], cm[1, 0], cm[1, 1]
    accuracy = (TP + TN) / np.sum(cm) # % positive out of all predicted positives
    precision = TP / (TP+FP) # % positive out of all predicted positives
    recall =  TP / (TP+FN) # % positive out of all supposed to be positives
    specificity = TN / (TN+FP) # % negative out of all supposed to be negatives
    f1 = 2*precision*recall / (precision + recall)
    stats_summary = '[Summary Statistics]\nAccuracy = {:.2%} | Precision = {:.2%} | Recall = {:.2%} | Specificity = {:.2%} | F1 Score = {:.2%}'.format(accuracy, precision, recall, specificity, f1)
    print(stats_summary)

# %%
create_charts3(cnn3, cnn_model3)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1976: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# [Summary Statistics]
# Accuracy = 63.86% | Precision = 64.98% | Recall = 65.58% | Specificity = 62.00% | F1 Score = 65.28%

# %% [markdown]
# **Superimposing Accuracy and Loss graphs for different Kernel sizes**

# %%
EPOCHS=50

record_arr1 = np.array([cnn_model1.history['loss'][0], cnn_model1.history['accuracy'][0]])
for i in range(1, EPOCHS):
    new_row1 = np.array([cnn_model1.history['loss'][i], cnn_model1.history['accuracy'][i]])
    record_arr1 = np.row_stack((record_arr1, new_row1))
    
record_df1 = pd.DataFrame(record_arr1, columns=["loss", "acc"])

record_arr2 = np.array([cnn_model2.history['loss'][0], cnn_model2.history['accuracy'][0]])
for i in range(1, EPOCHS):
    new_row2 = np.array([cnn_model2.history['loss'][i], cnn_model2.history['accuracy'][i]])
    record_arr2 = np.row_stack((record_arr2, new_row2))
    
record_df2 = pd.DataFrame(record_arr2, columns=["loss", "acc"])

record_arr3 = np.array([cnn_model3.history['loss'][0], cnn_model3.history['accuracy'][0]])
for i in range(1, EPOCHS):
    new_row3 = np.array([cnn_model3.history['loss'][i], cnn_model3.history['accuracy'][i]])
    record_arr3 = np.row_stack((record_arr3, new_row3))
    
record_df3 = pd.DataFrame(record_arr3, columns=["loss", "acc"])



#print curve
fig = plt.figure(figsize=(13, 10))
plt.subplot(2,2,1)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss of conducted experiments vs. Epochs')
plt.plot(np.arange(0, EPOCHS), record_df1["loss"], label='Kernel size=3')
plt.plot(np.arange(0, EPOCHS), record_df2["loss"], label='Kernel size=5')
plt.plot(np.arange(0, EPOCHS), record_df3["loss"], label='Kernel size=7')

plt.legend()
# fig.saveplot(path1+'Loss')
plt.subplot(2,2,2)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training Accuracy of conducted experiments vs. Epochs')
plt.plot(np.arange(0, EPOCHS), record_df1["acc"], label='Kernel size=3')
plt.plot(np.arange(0, EPOCHS), record_df2["acc"], label='Kernel size=5')
plt.plot(np.arange(0, EPOCHS), record_df3["acc"], label='Kernel size=7')

plt.legend()
plt.tight_layout()

plt.show()

save_path='/content/drive/MyDrive/New Images'
fig.savefig(save_path+'New-28_KernelSize')
